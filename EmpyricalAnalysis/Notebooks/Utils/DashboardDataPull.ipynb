# %% [markdown]
# ## Building a plugin to pull data directly from dashbaord
#
# ### generate_ifcb_pids
# this creates a list of pids that it will references as it pulls data files from a set date time range
# input the time of interest you want to look at
#
# I can not get the api to work for filtering so hacky way to get around is just make a list of all the pids and then filter that to just the times you want so that is what get_ifcb_bins_datetime_filtered does
#
# ### Hit API for required files
# download_file -- helper function that pulls api and saves without overwriting if the file already exists
# download_ifcb_bins - used download_file to loop over PID list for specified file types -- probably easy to add other metadata stuff

# %%
## Does not currently work the API does not use standard date time or I have something wrong so this just makes a list of all PIDs in a dataset

import requests
import pandas as pd
from datetime import datetime

def get_ifcb_bins_datetime(base_url: str,
                           dataset: str,
                           start: str,
                           end: str) -> pd.DataFrame:
    """
    Query the IFCB dashboard API to get a list of bins (PIDs)
    for a given dataset and datetime range.

    Parameters
    ----------
    base_url : str
        e.g. "https://habon-ifcb.whoi.edu"
    dataset : str
        e.g. "dagm01"
    start, end : str
        ISO-like datetime strings, e.g. "2023-12-14T09:00:00".

    Returns
    -------
    DataFrame with at least a 'pid' column.
    """
    base_url = base_url.rstrip("/")
    url = (
        f"{base_url}/api/list_bins"
        f"?dataset={dataset}"
        f"&start_datetime={start}"
        f"&end_datetime={end}"
    )

    r = requests.get(url)
    r.raise_for_status()
    data = r.json()["data"]
    bins_df = pd.DataFrame(data)
    return bins_df
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
base_url = "https://habon-ifcb.whoi.edu"
dataset = "nauset"

start_dt = "2024-04-02T00:00:00"
end_dt   = "2024-04-02T23:00:00"

bins_df = get_ifcb_bins_datetime(base_url, dataset, start_dt, end_dt)
bins = bins_df["pid"].tolist()

print(f"Found {len(bins)} bins between {start_dt} and {end_dt}")
print(bins[:5])
# Out:
# Found 52455 bins between 2024-04-02T00:00:00 and 2024-04-02T23:00:00
# ['D20120318T192302_IFCB000', 'D20120318T192302_IFCB010', 'D20120318T220052_IFCB000', 'D20120318T220052_IFCB010', 'D20120319T135125_IFCB010']

# %% [markdown]
# ### Above does not seem to actual fiulter by time which is anyoing I should look for/ ask around how API works to see if we can get it to work but simple work around is to just filter this list off all pids to the times I want
#
# #### that is what is below use for now

# %%
import requests
import pandas as pd

def get_ifcb_bins_datetime_filtered(base_url: str,
                                    dataset: str,
                                    start: str,
                                    end: str) -> pd.DataFrame:
    """
    Get all bins for a dataset from /api/list_bins, then filter by sample_time
    between 'start' and 'end' (inclusive).

    Parameters
    ----------
    base_url : e.g. "https://habon-ifcb.whoi.edu"
    dataset  : e.g. "nauset"
    start, end : ISO-like datetime strings, e.g. "2025-06-25T09:00:00Z"

    Returns
    -------
    DataFrame with only bins in the requested time window.
    """
    base_url = base_url.rstrip("/")
    url = f"{base_url}/api/list_bins?dataset={dataset}"

    r = requests.get(url)
    r.raise_for_status()
    data = r.json()["data"]

    df = pd.DataFrame(data)

    # Adjust this column name if needed, but on HABON it should be 'sample_time'
    df["sample_time"] = pd.to_datetime(df["sample_time"])

    start_dt = pd.to_datetime(start)
    end_dt   = pd.to_datetime(end)

    mask = (df["sample_time"] >= start_dt) & (df["sample_time"] <= end_dt)
    return df.loc[mask].copy()

# %%
## example usage ##

###URL OPTIONS
## PERCY: http://percy.whoi.edu:8000
## HABON: https://habon-ifcb.whoi.edu

base_url = "https://habon-ifcb.whoi.edu"
dataset = "hablab_jata_highV"

start_dt = "2026-01-03T00:00:00Z"
end_dt   = "2026-01-30T12:00:00Z"


bins_df = get_ifcb_bins_datetime_filtered(base_url, dataset, start_dt, end_dt)
bins = bins_df["pid"].tolist()

print(f"Found {len(bins)} bins between {start_dt} and {end_dt}")
print(bins[:5])
# Out:
# Found 54 bins between 2026-01-03T00:00:00Z and 2026-01-30T12:00:00Z
# ['D20260124T004704_IFCB124', 'D20260124T011921_IFCB149', 'D20260124T013328_IFCB124', 'D20260124T020550_IFCB149', 'D20260124T021953_IFCB124']

# %% [markdown]
# ### with PID list now download ADC, HDR, and Class lists
#
# loops through PID list and hits dashboard API for adc, hdr and class lists

# %%
from pathlib import Path
from typing import Dict, List

def download_file(url: str,
                  dest_path: Path,
                  overwrite: bool = False,
                  timeout: int = 30) -> bool:
    if dest_path.exists() and not overwrite:
        print(f"[skip] {dest_path} already exists")
        return True

    try:
        r = requests.get(url, timeout=timeout)
    except Exception as e:
        print(f"[error] GET {url} failed: {e}")
        return False

    if r.status_code == 200:
        dest_path.parent.mkdir(parents=True, exist_ok=True)
        dest_path.write_bytes(r.content)
        print(f"[ok]   {url} -> {dest_path}")
        return True
    elif r.status_code == 404:
        print(f"[404]  {url} not found")
        return False
    else:
        print(f"[{r.status_code}] {url} (no download)")
        return False


def download_ifcb_bins(base_url: str,
                       dataset: str,
                       pids: List[str],
                       dest_dir: str,
                       download_adc: bool = True,
                       download_hdr: bool = True,
                       download_class: bool = True,
                       class_suffix: str = "_class_vNone.csv",
                       overwrite: bool = False,
                       timeout: int = 30) -> Dict[str, Dict[str, Path]]:
    base_url = base_url.rstrip("/")
    dest_root = Path(dest_dir)
    files_downloaded: Dict[str, Dict[str, Path]] = {}

    for pid in pids:
        print(f"\n=== {pid} ===")
        pid_results: Dict[str, Path] = {}

        if download_adc:
            adc_url = f"{base_url}/{dataset}/{pid}.adc"
            adc_path = dest_root / dataset / f"{pid}.adc"
            if download_file(adc_url, adc_path, overwrite=overwrite, timeout=timeout):
                pid_results["adc"] = adc_path

        if download_hdr:
            hdr_url = f"{base_url}/{dataset}/{pid}.hdr"
            hdr_path = dest_root / dataset / f"{pid}.hdr"
            if download_file(hdr_url, hdr_path, overwrite=overwrite, timeout=timeout):
                pid_results["hdr"] = hdr_path

        if download_class:
            class_filename = f"{pid}{class_suffix}"
            class_url = f"{base_url}/{dataset}/{class_filename}"
            class_path = dest_root / dataset / class_filename
            if download_file(class_url, class_path, overwrite=overwrite, timeout=timeout):
                pid_results["class"] = class_path

        if pid_results:
            files_downloaded[pid] = pid_results

    return files_downloaded

# %% [markdown]
# # example usage

# %%
## example usage

# 1) Filter bins by datetime
bins_df = get_ifcb_bins_datetime_filtered(
    base_url = "https://habon-ifcb.whoi.edu",
    dataset="hablab_jata_highV",
    start = start_dt,
    end   = end_dt
)
bins = bins_df["pid"].tolist()

# 2) Download files only for those bins
files = download_ifcb_bins(
    base_url = "https://habon-ifcb.whoi.edu",
    dataset="hablab_jata_highV",
    pids=bins,
    dest_dir="../../IFCBData/dilExp/jataHighV/",
    class_suffix="_class_scores.csv",  # change if nauset uses a different suffix -- just go to the dashboard and copy class link as text and see what it looks like if unsure
)
# Out:
# === D20260124T004704_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T004704_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T004704_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T004704_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T004704_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T004704_IFCB124_class_scores.csv not found
#
# === D20260124T011921_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T011921_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T011921_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T011921_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T011921_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T011921_IFCB149_class_scores.csv not found
#
# === D20260124T013328_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T013328_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T013328_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T013328_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T013328_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T013328_IFCB124_class_scores.csv not found
#
# === D20260124T020550_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T020550_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T020550_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T020550_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T020550_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T020550_IFCB149_class_scores.csv not found
#
# === D20260124T021953_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T021953_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T021953_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T021953_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T021953_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T021953_IFCB124_class_scores.csv not found
#
# === D20260124T025219_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T025219_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T025219_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T025219_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T025219_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T025219_IFCB149_class_scores.csv not found
#
# === D20260124T030619_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T030619_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T030619_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T030619_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T030619_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T030619_IFCB124_class_scores.csv not found
#
# === D20260124T033848_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T033848_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T033848_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T033848_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T033848_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T033848_IFCB149_class_scores.csv not found
#
# === D20260124T035244_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T035244_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T035244_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T035244_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T035244_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T035244_IFCB124_class_scores.csv not found
#
# === D20260124T042517_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T042517_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T042517_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T042517_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T042517_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T042517_IFCB149_class_scores.csv not found
#
# === D20260124T043909_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T043909_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T043909_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T043909_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T043909_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T043909_IFCB124_class_scores.csv not found
#
# === D20260124T051146_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T051146_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T051146_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T051146_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T051146_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T051146_IFCB149_class_scores.csv not found
#
# === D20260124T052534_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T052534_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T052534_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T052534_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T052534_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T052534_IFCB124_class_scores.csv not found
#
# === D20260124T055815_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T055815_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T055815_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T055815_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T055815_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T055815_IFCB149_class_scores.csv not found
#
# === D20260124T061200_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T061200_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T061200_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T061200_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T061200_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T061200_IFCB124_class_scores.csv not found
#
# === D20260124T064444_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T064444_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T064444_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T064444_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T064444_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T064444_IFCB149_class_scores.csv not found
#
# === D20260124T065825_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T065825_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T065825_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T065825_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T065825_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T065825_IFCB124_class_scores.csv not found
#
# === D20260124T074452_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T074452_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T074452_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T074452_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T074452_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T074452_IFCB124_class_scores.csv not found
#
# === D20260124T081741_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T081741_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T081741_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T081741_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T081741_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T081741_IFCB149_class_scores.csv not found
#
# === D20260124T083118_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T083118_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T083118_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T083118_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T083118_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T083118_IFCB124_class_scores.csv not found
#
# === D20260124T090410_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T090410_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T090410_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T090410_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T090410_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T090410_IFCB149_class_scores.csv not found
#
# === D20260124T091744_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T091744_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T091744_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T091744_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T091744_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T091744_IFCB124_class_scores.csv not found
#
# === D20260124T095039_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T095039_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T095039_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T095039_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T095039_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T095039_IFCB149_class_scores.csv not found
#
# === D20260124T100409_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T100409_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T100409_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T100409_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T100409_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T100409_IFCB124_class_scores.csv not found
#
# === D20260124T103708_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T103708_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T103708_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T103708_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T103708_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T103708_IFCB149_class_scores.csv not found
#
# === D20260124T105035_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T105035_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T105035_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T105035_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T105035_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T105035_IFCB124_class_scores.csv not found
#
# === D20260124T112337_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T112337_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T112337_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T112337_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T112337_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T112337_IFCB149_class_scores.csv not found
#
# === D20260124T113700_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T113700_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T113700_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T113700_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T113700_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T113700_IFCB124_class_scores.csv not found
#
# === D20260124T121006_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T121006_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T121006_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T121006_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T121006_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T121006_IFCB149_class_scores.csv not found
#
# === D20260124T122324_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T122324_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T122324_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T122324_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T122324_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T122324_IFCB124_class_scores.csv not found
#
# === D20260124T125635_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T125635_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T125635_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T125635_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T125635_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T125635_IFCB149_class_scores.csv not found
#
# === D20260124T130950_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T130950_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T130950_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T130950_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T130950_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T130950_IFCB124_class_scores.csv not found
#
# === D20260124T135616_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T135616_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T135616_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T135616_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T135616_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T135616_IFCB124_class_scores.csv not found
#
# === D20260124T142933_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T142933_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T142933_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T142933_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T142933_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T142933_IFCB149_class_scores.csv not found
#
# === D20260124T144240_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T144240_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T144240_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T144240_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T144240_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T144240_IFCB124_class_scores.csv not found
#
# === D20260124T151602_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T151602_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T151602_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T151602_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T151602_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T151602_IFCB149_class_scores.csv not found
#
# === D20260124T152906_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T152906_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T152906_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T152906_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T152906_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T152906_IFCB124_class_scores.csv not found
#
# === D20260124T160231_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T160231_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T160231_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T160231_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T160231_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T160231_IFCB149_class_scores.csv not found
#
# === D20260124T161532_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T161532_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T161532_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T161532_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T161532_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T161532_IFCB124_class_scores.csv not found
#
# === D20260124T164900_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T164900_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T164900_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T164900_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T164900_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T164900_IFCB149_class_scores.csv not found
#
# === D20260124T170157_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T170157_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T170157_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T170157_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T170157_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T170157_IFCB124_class_scores.csv not found
#
# === D20260124T173529_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T173529_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T173529_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T173529_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T173529_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T173529_IFCB149_class_scores.csv not found
#
# === D20260124T174822_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T174822_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T174822_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T174822_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T174822_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T174822_IFCB124_class_scores.csv not found
#
# === D20260124T182156_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T182156_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T182156_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T182156_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T182156_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T182156_IFCB149_class_scores.csv not found
#
# === D20260124T183448_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T183448_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T183448_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T183448_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T183448_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T183448_IFCB124_class_scores.csv not found
#
# === D20260124T190825_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T190825_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T190825_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T190825_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T190825_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T190825_IFCB149_class_scores.csv not found
#
# === D20260124T192114_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T192114_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T192114_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T192114_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T192114_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T192114_IFCB124_class_scores.csv not found
#
# === D20260124T195454_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T195454_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T195454_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T195454_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T195454_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T195454_IFCB149_class_scores.csv not found
#
# === D20260124T200739_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T200739_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T200739_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T200739_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T200739_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T200739_IFCB124_class_scores.csv not found
#
# === D20260124T204123_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T204123_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T204123_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T204123_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T204123_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T204123_IFCB149_class_scores.csv not found
#
# === D20260124T205404_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T205404_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T205404_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T205404_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T205404_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T205404_IFCB124_class_scores.csv not found
#
# === D20260124T212752_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T212752_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T212752_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T212752_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T212752_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T212752_IFCB149_class_scores.csv not found
#
# === D20260124T214030_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T214030_IFCB124.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T214030_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T214030_IFCB124.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T214030_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T214030_IFCB124_class_scores.csv not found
#
# === D20260124T221421_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T221421_IFCB149.adc -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T221421_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T221421_IFCB149.hdr -> ../../IFCBData/dilExp/jataHighV/hablab_jata_highV/D20260124T221421_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_highV/D20260124T221421_IFCB149_class_scores.csv not found
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T080806_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T080806_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T080806_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T080806_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T080806_IFCB124_class_scores.csv not found
#
# === D20260124T084056_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T084056_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T084056_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T084056_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T084056_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T084056_IFCB149_class_scores.csv not found
#
# === D20260124T085432_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T085432_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T085432_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T085432_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T085432_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T085432_IFCB124_class_scores.csv not found
#
# === D20260124T092725_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T092725_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T092725_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T092725_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T092725_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T092725_IFCB149_class_scores.csv not found
#
# === D20260124T094057_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T094057_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T094057_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T094057_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T094057_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T094057_IFCB124_class_scores.csv not found
#
# === D20260124T101354_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T101354_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T101354_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T101354_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T101354_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T101354_IFCB149_class_scores.csv not found
#
# === D20260124T102723_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T102723_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T102723_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T102723_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T102723_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T102723_IFCB124_class_scores.csv not found
#
# === D20260124T110023_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T110023_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T110023_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T110023_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T110023_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T110023_IFCB149_class_scores.csv not found
#
# === D20260124T111347_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T111347_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T111347_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T111347_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T111347_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T111347_IFCB124_class_scores.csv not found
#
# === D20260124T114652_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T114652_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T114652_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T114652_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T114652_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T114652_IFCB149_class_scores.csv not found
#
# === D20260124T120012_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T120012_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T120012_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T120012_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T120012_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T120012_IFCB124_class_scores.csv not found
#
# === D20260124T123320_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T123320_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T123320_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T123320_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T123320_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T123320_IFCB149_class_scores.csv not found
#
# === D20260124T124637_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T124637_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T124637_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T124637_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T124637_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T124637_IFCB124_class_scores.csv not found
#
# === D20260124T131949_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T131949_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T131949_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T131949_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T131949_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T131949_IFCB149_class_scores.csv not found
#
# === D20260124T133303_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T133303_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T133303_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T133303_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T133303_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T133303_IFCB124_class_scores.csv not found
#
# === D20260124T140618_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T140618_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T140618_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T140618_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T140618_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T140618_IFCB149_class_scores.csv not found
#
# === D20260124T141928_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T141928_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T141928_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T141928_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T141928_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T141928_IFCB124_class_scores.csv not found
#
# === D20260124T145247_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T145247_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T145247_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T145247_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T145247_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T145247_IFCB149_class_scores.csv not found
#
# === D20260124T150554_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T150554_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T150554_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T150554_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T150554_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T150554_IFCB124_class_scores.csv not found
#
# === D20260124T153916_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T153916_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T153916_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T153916_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T153916_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T153916_IFCB149_class_scores.csv not found
#
# === D20260124T155219_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T155219_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T155219_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T155219_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T155219_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T155219_IFCB124_class_scores.csv not found
#
# === D20260124T162545_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T162545_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T162545_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T162545_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T162545_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T162545_IFCB149_class_scores.csv not found
#
# === D20260124T163844_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T163844_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T163844_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T163844_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T163844_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T163844_IFCB124_class_scores.csv not found
#
# === D20260124T171214_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T171214_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T171214_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T171214_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T171214_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T171214_IFCB149_class_scores.csv not found
#
# === D20260124T172510_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T172510_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T172510_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T172510_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T172510_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T172510_IFCB124_class_scores.csv not found
#
# === D20260124T175843_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T175843_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T175843_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T175843_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T175843_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T175843_IFCB149_class_scores.csv not found
#
# === D20260124T181136_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T181136_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T181136_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T181136_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T181136_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T181136_IFCB124_class_scores.csv not found
#
# === D20260124T184511_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T184511_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T184511_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T184511_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T184511_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T184511_IFCB149_class_scores.csv not found
#
# === D20260124T185801_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T185801_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T185801_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T185801_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T185801_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T185801_IFCB124_class_scores.csv not found
#
# === D20260124T193139_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T193139_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T193139_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T193139_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T193139_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T193139_IFCB149_class_scores.csv not found
#
# === D20260124T194427_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T194427_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T194427_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T194427_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T194427_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T194427_IFCB124_class_scores.csv not found
#
# === D20260124T203052_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T203052_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T203052_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T203052_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T203052_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T203052_IFCB124_class_scores.csv not found
#
# === D20260124T210437_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T210437_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T210437_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T210437_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T210437_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T210437_IFCB149_class_scores.csv not found
#
# === D20260124T211717_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T211717_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T211717_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T211717_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T211717_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T211717_IFCB124_class_scores.csv not found
#
# === D20260124T215106_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T215106_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T215106_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T215106_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T215106_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T215106_IFCB149_class_scores.csv not found
#
# === D20260124T220343_IFCB124 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T220343_IFCB124.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T220343_IFCB124.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T220343_IFCB124.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T220343_IFCB124.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T220343_IFCB124_class_scores.csv not found
#
# === D20260124T223735_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T223735_IFCB149.adc -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T223735_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T223735_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T223735_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T223735_IFCB149_class_scores.csv not found
