# %% [markdown]
# ## Building a plugin to pull data directly from dashbaord
#
# ### generate_ifcb_pids
# this creates a list of pids that it will references as it pulls data files from a set date time range
# input the time of interest you want to look at
#
# I can not get the api to work for filtering so hacky way to get around is just make a list of all the pids and then filter that to just the times you want so that is what get_ifcb_bins_datetime_filtered does
#
# ### Hit API for required files
# download_file -- helper function that pulls api and saves without overwriting if the file already exists
# download_ifcb_bins - used download_file to loop over PID list for specified file types -- probably easy to add other metadata stuff

# %%
## Pull bins (PIDs) using currently supported API endpoint

import requests
import pandas as pd
from io import StringIO

def get_ifcb_bins_datetime(base_url: str,
                           dataset: str,
                           start: str,
                           end: str,
                           include_skip: bool = True,
                           timeout: int = 60) -> pd.DataFrame:
    """
    Get IFCB bins for a dataset and date range using /api/export_metadata.

    Parameters
    ----------
    base_url : str
        e.g. "https://habon-ifcb.whoi.edu"
    dataset : str
        e.g. "nauset"
    start, end : str
        ISO-like datetime strings, e.g. "2024-04-02T00:00:00Z".
    include_skip : bool
        If True, include skipped bins in the export.
    timeout : int
        Request timeout (seconds).

    Returns
    -------
    DataFrame with at least a 'pid' column, typically including 'sample_time'.
    """
    base_url = base_url.rstrip("/")
    export_url = f"{base_url}/api/export_metadata/{dataset}"
    params = {
        "start_date": start,
        "end_date": end,
        "include_skip": str(include_skip).lower(),
    }

    r = requests.get(export_url, params=params, timeout=timeout)
    r.raise_for_status()

    # export_metadata returns CSV, not JSON
    bins_df = pd.read_csv(StringIO(r.text))

    if "pid" not in bins_df.columns:
        raise ValueError(
            f"Expected 'pid' column from {export_url}, got columns: {bins_df.columns.tolist()}"
        )

    return bins_df

# %%
base_url = "https://habon-ifcb.whoi.edu"
dataset = "nauset"

start_dt = "2024-04-02T00:00:00"
end_dt   = "2024-04-02T23:00:00"

bins_df = get_ifcb_bins_datetime(base_url, dataset, start_dt, end_dt)
bins = bins_df["pid"].tolist()

print(f"Found {len(bins)} bins between {start_dt} and {end_dt}")
print(bins[:5])
# Out:
# Found 59 bins between 2024-04-02T00:00:00 and 2024-04-02T23:00:00
# ['D20240402T001855_IFCB124', 'D20240402T004255_IFCB124', 'D20240402T010656_IFCB124', 'D20240402T013056_IFCB124', 'D20240402T015457_IFCB124']

# %% [markdown]
# ### Above does not seem to actual fiulter by time which is anyoing I should look for/ ask around how API works to see if we can get it to work but simple work around is to just filter this list off all pids to the times I want
#
# #### that is what is below use for now

# %%
import pandas as pd

def get_ifcb_bins_datetime_filtered(base_url: str,
                                    dataset: str,
                                    start: str,
                                    end: str,
                                    include_skip: bool = True) -> pd.DataFrame:
    """
    Get bins from /api/export_metadata and return only rows in [start, end].

    This is kept as a safety filter in case server-side time filtering behavior
    differs across deployments.
    """
    df = get_ifcb_bins_datetime(
        base_url=base_url,
        dataset=dataset,
        start=start,
        end=end,
        include_skip=include_skip,
    )

    if "sample_time" not in df.columns:
        raise ValueError(
            f"Expected 'sample_time' column for filtering, got: {df.columns.tolist()}"
        )

    df["sample_time"] = pd.to_datetime(df["sample_time"], utc=True)
    start_dt = pd.to_datetime(start, utc=True)
    end_dt = pd.to_datetime(end, utc=True)

    mask = (df["sample_time"] >= start_dt) & (df["sample_time"] <= end_dt)
    return df.loc[mask].copy()

# %%
## example usage ##

###URL OPTIONS
## PERCY: http://percy.whoi.edu:8000
## HABON: https://habon-ifcb.whoi.edu

base_url = "https://habon-ifcb.whoi.edu"
dataset = "hablab_AlexHighV"

start_dt = "2026-03-04T00:00:00Z"
end_dt   = "2026-03-06T12:00:00Z"


bins_df = get_ifcb_bins_datetime_filtered(base_url, dataset, start_dt, end_dt)
bins = bins_df["pid"].tolist()


print(f"Found {len(bins)} bins between {start_dt} and {end_dt}")
print(bins[:5])
# Out:
# Found 50 bins between 2026-03-04T00:00:00Z and 2026-03-06T12:00:00Z
# ['D20260304T202558_IFCB149', 'D20260304T204912_IFCB149', 'D20260304T211303_IFCB149', 'D20260304T215934_IFCB149', 'D20260304T224605_IFCB149']

# %%
print(bins_df.columns.tolist())
print(bins_df.head())
# Out:
# ['pid', 'sample_time', 'skip']
#                         pid               sample_time   skip
# 0  D20260212T232705_IFCB124 2026-02-12 23:27:05+00:00  False
# 1  D20260212T235018_IFCB124 2026-02-12 23:50:18+00:00  False
# 2  D20260213T001330_IFCB124 2026-02-13 00:13:30+00:00  False
# 3  D20260213T003642_IFCB124 2026-02-13 00:36:42+00:00  False
# 4  D20260213T005956_IFCB124 2026-02-13 00:59:56+00:00  False

# %% [markdown]
# ### with PID list now download ADC, HDR, and Class lists
#
# loops through PID list and hits dashboard API for adc, hdr and class lists

# %%
from pathlib import Path
from typing import Dict, List

def download_file(url: str,
                  dest_path: Path,
                  overwrite: bool = False,
                  timeout: int = 30) -> bool:
    if dest_path.exists() and not overwrite:
        print(f"[skip] {dest_path} already exists")
        return True

    try:
        r = requests.get(url, timeout=timeout)
    except Exception as e:
        print(f"[error] GET {url} failed: {e}")
        return False

    if r.status_code == 200:
        dest_path.parent.mkdir(parents=True, exist_ok=True)
        dest_path.write_bytes(r.content)
        print(f"[ok]   {url} -> {dest_path}")
        return True
    elif r.status_code == 404:
        print(f"[404]  {url} not found")
        return False
    else:
        print(f"[{r.status_code}] {url} (no download)")
        return False


def download_ifcb_bins(base_url: str,
                       dataset: str,
                       pids: List[str],
                       dest_dir: str,
                       download_adc: bool = True,
                       download_hdr: bool = True,
                       download_class: bool = True,
                       class_suffix: str = "_class_vNone.csv",
                       overwrite: bool = False,
                       timeout: int = 30) -> Dict[str, Dict[str, Path]]:
    base_url = base_url.rstrip("/")
    dest_root = Path(dest_dir)
    files_downloaded: Dict[str, Dict[str, Path]] = {}

    for pid in pids:
        print(f"\n=== {pid} ===")
        pid_results: Dict[str, Path] = {}

        if download_adc:
            adc_url = f"{base_url}/{dataset}/{pid}.adc"
            adc_path = dest_root / dataset / f"{pid}.adc"
            if download_file(adc_url, adc_path, overwrite=overwrite, timeout=timeout):
                pid_results["adc"] = adc_path

        if download_hdr:
            hdr_url = f"{base_url}/{dataset}/{pid}.hdr"
            hdr_path = dest_root / dataset / f"{pid}.hdr"
            if download_file(hdr_url, hdr_path, overwrite=overwrite, timeout=timeout):
                pid_results["hdr"] = hdr_path

        if download_class:
            class_filename = f"{pid}{class_suffix}"
            class_url = f"{base_url}/{dataset}/{class_filename}"
            class_path = dest_root / dataset / class_filename
            if download_file(class_url, class_path, overwrite=overwrite, timeout=timeout):
                pid_results["class"] = class_path

        if pid_results:
            files_downloaded[pid] = pid_results

    return files_downloaded

# %% [markdown]
# # example usage

# %%
## example usage

# 1) Filter bins by datetime
bins_df = get_ifcb_bins_datetime_filtered(
    base_url = "https://habon-ifcb.whoi.edu",
    dataset="hablab_AlexHighV",
    start = start_dt,
    end   = end_dt
)
bins = bins_df["pid"].tolist()

# 2) Download files only for those bins
files = download_ifcb_bins(
    base_url = "https://habon-ifcb.whoi.edu",
    dataset="hablab_AlexHighV",
    pids=bins,
    dest_dir="../../IFCBData/dilExp/Alex/",
    class_suffix="_class_scores.csv",  # change if nauset uses a different suffix -- just go to the dashboard and copy class link as text and see what it looks like if unsure
)
# Out:
# === D20260304T202558_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T202558_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260304T202558_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T202558_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260304T202558_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T202558_IFCB149_class_scores.csv not found
#
# === D20260304T204912_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T204912_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260304T204912_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T204912_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260304T204912_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T204912_IFCB149_class_scores.csv not found
#
# === D20260304T211303_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T211303_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260304T211303_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T211303_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260304T211303_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T211303_IFCB149_class_scores.csv not found
#
# === D20260304T215934_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T215934_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260304T215934_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T215934_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260304T215934_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T215934_IFCB149_class_scores.csv not found
#
# === D20260304T224605_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T224605_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260304T224605_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T224605_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260304T224605_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T224605_IFCB149_class_scores.csv not found
#
# === D20260304T233236_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T233236_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260304T233236_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T233236_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260304T233236_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260304T233236_IFCB149_class_scores.csv not found
#
# === D20260305T001907_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T001907_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T001907_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T001907_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T001907_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T001907_IFCB149_class_scores.csv not found
#
# === D20260305T010538_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T010538_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T010538_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T010538_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T010538_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T010538_IFCB149_class_scores.csv not found
#
# === D20260305T015208_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T015208_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T015208_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T015208_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T015208_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T015208_IFCB149_class_scores.csv not found
#
# === D20260305T023839_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T023839_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T023839_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T023839_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T023839_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T023839_IFCB149_class_scores.csv not found
#
# === D20260305T041141_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T041141_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T041141_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T041141_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T041141_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T041141_IFCB149_class_scores.csv not found
#
# === D20260305T045812_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T045812_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T045812_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T045812_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T045812_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T045812_IFCB149_class_scores.csv not found
#
# === D20260305T054443_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T054443_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T054443_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T054443_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T054443_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T054443_IFCB149_class_scores.csv not found
#
# === D20260305T063113_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T063113_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T063113_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T063113_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T063113_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T063113_IFCB149_class_scores.csv not found
#
# === D20260305T071744_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T071744_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T071744_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T071744_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T071744_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T071744_IFCB149_class_scores.csv not found
#
# === D20260305T080415_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T080415_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T080415_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T080415_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T080415_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T080415_IFCB149_class_scores.csv not found
#
# === D20260305T085046_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T085046_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T085046_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T085046_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T085046_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T085046_IFCB149_class_scores.csv not found
#
# === D20260305T093716_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T093716_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T093716_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T093716_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T093716_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T093716_IFCB149_class_scores.csv not found
#
# === D20260305T102347_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T102347_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T102347_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T102347_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T102347_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T102347_IFCB149_class_scores.csv not found
#
# === D20260305T115649_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T115649_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T115649_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T115649_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T115649_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T115649_IFCB149_class_scores.csv not found
#
# === D20260305T124320_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T124320_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T124320_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T124320_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T124320_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T124320_IFCB149_class_scores.csv not found
#
# === D20260305T132951_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T132951_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T132951_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T132951_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexHighV/D20260305T132951_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexHighV/D20260305T132951_IFCB149_class_scores.csv not found
# [ok]   https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T223735_IFCB149.hdr -> ../../IFCBData/dilExp/jataLowV/hablab_jata_lowV/D20260124T223735_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_jata_lowV/D20260124T223735_IFCB149_class_scores.csv not found

# %%
## Or use your own prebuilt PID bins list 
## import json pid list if you have it saved already, otherwise use the above functions to pull bins and save as json for future use

import json

with open("../../IFCBData/PIDLists/mvco_test.json", "r") as f:
    bins = json.load(f)

if not isinstance(bins, list):
    raise ValueError("PID JSON should be a list of PID strings.")

bins = [str(pid) for pid in bins]
print(bins[:5])
print(f"Loaded {len(bins)} bins from JSON file")
# Out:
# ['IFCB5_2017_001_121620', 'IFCB5_2017_002_122101', 'IFCB5_2017_003_151126', 'IFCB5_2017_004_121005', 'IFCB5_2017_005_121128']
# Loaded 139 bins from JSON file

# %%
### Be sure to check base url and dataset is matched with PID source
files = download_ifcb_bins(
    base_url = "https://habon-ifcb.whoi.edu",
    dataset
IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170530T120055_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170530T120055_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170530T120055_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170530T120055_IFCB010.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170530T120055_IFCB010_class_scores.csv -> ../../IFCBData/dilExp/mvco/mvco/D20170530T120055_IFCB010_class_scores.csv
#
# === D20170531T122009_IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170531T122009_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170531T122009_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170531T122009_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170531T122009_IFCB010.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170531T122009_IFCB010_class_scores.csv -> ../../IFCBData/dilExp/mvco/mvco/D20170531T122009_IFCB010_class_scores.csv
#
# === D20170601T121917_IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170601T121917_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170601T121917_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170601T121917_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170601T121917_IFCB010.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170601T121917_IFCB010_class_scores.csv -> ../../IFCBData/dilExp/mvco/mvco/D20170601T121917_IFCB010_class_scores.csv
#
# === D20170602T121552_IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170602T121552_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170602T121552_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170602T121552_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170602T121552_IFCB010.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170602T121552_IFCB010_class_scores.csv -> ../../IFCBData/dilExp/mvco/mvco/D20170602T121552_IFCB010_class_scores.csv
#
# === D20170603T121232_IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170603T121232_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170603T121232_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170603T121232_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170603T121232_IFCB010.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170603T121232_IFCB010_class_scores.csv -> ../../IFCBData/dilExp/mvco/mvco/D20170603T121232_IFCB010_class_scores.csv
#
# === D20170604T120843_IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170604T120843_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170604T120843_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170604T120843_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170604T120843_IFCB010.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170604T120843_IFCB010_class_scores.csv -> ../../IFCBData/dilExp/mvco/mvco/D20170604T120843_IFCB010_class_scores.csv
#
# === D20170605T120439_IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170605T120439_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170605T120439_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170605T120439_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170605T120439_IFCB010.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170605T120439_IFCB010_class_scores.csv -> ../../IFCBData/dilExp/mvco/mvco/D20170605T120439_IFCB010_class_scores.csv
#
# === D20170606T120041_IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170606T120041_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170606T120041_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170606T120041_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170606T120041_IFCB010.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170606T120041_IFCB010_class_scores.csv -> ../../IFCBData/dilExp/mvco/mvco/D20170606T120041_IFCB010_class_scores.csv
#
# === D20170607T121944_IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170607T121944_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170607T121944_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170607T121944_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170607T121944_IFCB010.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170607T121944_IFCB010_class_scores.csv -> ../../IFCBData/dilExp/mvco/mvco/D20170607T121944_IFCB010_class_scores.csv
#
# === D20170608T121527_IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170608T121527_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170608T121527_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170608T121527_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170608T121527_IFCB010.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170608T121527_IFCB010_class_scores.csv -> ../../IFCBData/dilExp/mvco/mvco/D20170608T121527_IFCB010_class_scores.csv
#
# === D20170609T121113_IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170609T121113_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170609T121113_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170609T121113_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170609T121113_IFCB010.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170609T121113_IFCB010_class_scores.csv -> ../../IFCBData/dilExp/mvco/mvco/D20170609T121113_IFCB010_class_scores.csv
#
# === D20170610T120636_IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170610T120636_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170610T120636_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170610T120636_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170610T120636_IFCB010.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170610T120636_IFCB010_class_scores.csv -> ../../IFCBData/dilExp/mvco/mvco/D20170610T120636_IFCB010_class_scores.csv
#
# === D20170611T120133_IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170611T120133_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170611T120133_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170611T120133_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170611T120133_IFCB010.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170611T120133_IFCB010_class_scores.csv -> ../../IFCBData/dilExp/mvco/mvco/D20170611T120133_IFCB010_class_scores.csv
#
# === D20170612T122014_IFCB010 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170612T122014_IFCB010.adc -> ../../IFCBData/dilExp/mvco/mvco/D20170612T122014_IFCB010.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20170612T122014_IFCB010.hdr -> ../../IFCBData/dilExp/mvco/mvco/D20170612T122014_IFCB010.hdr
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 13
#      10 else:
#      11     bins = list(bins)
# ---> 13 files = download_ifcb_bins(
#      14     base_url="https://habon-ifcb.whoi.edu",
#      15     dataset="mvco",
#      16     pids=bins,
#      17     dest_dir="../../IFCBData/dilExp/mvco/",
#      18     class_suffix="_class_scores.csv",  # change if needed by dataset
#      19     overwrite=False,
#      20     timeout=30,
#      21     download_adc=True,
#      22     download_hdr=True,
#      23     download_class=True,
#      24  )
#
# Cell In[15], line 65, in download_ifcb_bins(base_url, dataset, pids, dest_dir, download_adc, download_hdr, download_class, class_suffix, overwrite, timeout)
#      63     class_url = f"{base_url}/{dataset}/{class_filename}"
#      64     class_path = dest_root / dataset / class_filename
# ---> 65     if download_file(class_url, class_path, overwrite=overwrite, timeout=timeout):
#      66         pid_results["class"] = class_path
#      68 if pid_results:
#
# Cell In[15], line 13, in download_file(url, dest_path, overwrite, timeout)
#      10     return True
#      12 try:
# ---> 13     r = requests.get(url, timeout=timeout)
#      14 except Exception as e:
#      15     print(f"[error] GET {url} failed: {e}")
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/envs/carpentries/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:
