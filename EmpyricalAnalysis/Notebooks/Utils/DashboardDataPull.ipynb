# %% [markdown]
# ## Building a plugin to pull data directly from dashbaord
#
# ### generate_ifcb_pids
# this creates a list of pids that it will references as it pulls data files from a set date time range
# input the time of interest you want to look at
#
# I can not get the api to work for filtering so hacky way to get around is just make a list of all the pids and then filter that to just the times you want so that is what get_ifcb_bins_datetime_filtered does
#
# ### Hit API for required files
# download_file -- helper function that pulls api and saves without overwriting if the file already exists
# download_ifcb_bins - used download_file to loop over PID list for specified file types -- probably easy to add other metadata stuff

# %%
## Pull bins (PIDs) using currently supported API endpoint

import requests
import pandas as pd
from io import StringIO

def get_ifcb_bins_datetime(base_url: str,
                           dataset: str,
                           start: str,
                           end: str,
                           include_skip: bool = True,
                           timeout: int = 60) -> pd.DataFrame:
    """
    Get IFCB bins for a dataset and date range using /api/export_metadata.

    Parameters
    ----------
    base_url : str
        e.g. "https://habon-ifcb.whoi.edu"
    dataset : str
        e.g. "nauset"
    start, end : str
        ISO-like datetime strings, e.g. "2024-04-02T00:00:00Z".
    include_skip : bool
        If True, include skipped bins in the export.
    timeout : int
        Request timeout (seconds).

    Returns
    -------
    DataFrame with at least a 'pid' column, typically including 'sample_time'.
    """
    base_url = base_url.rstrip("/")
    export_url = f"{base_url}/api/export_metadata/{dataset}"
    params = {
        "start_date": start,
        "end_date": end,
        "include_skip": str(include_skip).lower(),
    }

    r = requests.get(export_url, params=params, timeout=timeout)
    r.raise_for_status()

    # export_metadata returns CSV, not JSON
    bins_df = pd.read_csv(StringIO(r.text))

    if "pid" not in bins_df.columns:
        raise ValueError(
            f"Expected 'pid' column from {export_url}, got columns: {bins_df.columns.tolist()}"
        )

    return bins_df

# %%
base_url = "https://habon-ifcb.whoi.edu"
dataset = "hablab_AlexHighV"

start_dt = "2026-03-04T21:00:00Z"
end_dt   = "2026-03-06T18:00:00Z"

bins_df = get_ifcb_bins_datetime(base_url, dataset, start_dt, end_dt)
bins = bins_df["pid"].tolist()

print(f"Found {len(bins)} bins between {start_dt} and {end_dt}")
print(bins[:5])
# Out:
# Found 51 bins between 2026-03-04T21:00:00Z and 2026-03-06T18:00:00Z
# ['D20260304T211303_IFCB149', 'D20260304T215934_IFCB149', 'D20260304T224605_IFCB149', 'D20260304T233236_IFCB149', 'D20260305T001907_IFCB149']

# %% [markdown]
# ### Above does not seem to actual fiulter by time which is anyoing I should look for/ ask around how API works to see if we can get it to work but simple work around is to just filter this list off all pids to the times I want
#
# #### that is what is below use for now

# %%
import pandas as pd

def get_ifcb_bins_datetime_filtered(base_url: str,
                                    dataset: str,
                                    start: str,
                                    end: str,
                                    include_skip: bool = True) -> pd.DataFrame:
    """
    Get bins from /api/export_metadata and return only rows in [start, end].

    This is kept as a safety filter in case server-side time filtering behavior
    differs across deployments.
    """
    df = get_ifcb_bins_datetime(
        base_url=base_url,
        dataset=dataset,
        start=start,
        end=end,
        include_skip=include_skip,
    )

    if "sample_time" not in df.columns:
        raise ValueError(
            f"Expected 'sample_time' column for filtering, got: {df.columns.tolist()}"
        )

    df["sample_time"] = pd.to_datetime(df["sample_time"], utc=True)
    start_dt = pd.to_datetime(start, utc=True)
    end_dt = pd.to_datetime(end, utc=True)

    mask = (df["sample_time"] >= start_dt) & (df["sample_time"] <= end_dt)
    return df.loc[mask].copy()

# %%
## example usage ##

###URL OPTIONS
## PERCY: http://percy.whoi.edu:8000
## HABON: https://habon-ifcb.whoi.edu

base_url = "https://habon-ifcb.whoi.edu"
dataset = "hablab_AlexLowV"

start_dt = "2026-03-04T21:00:00Z"
end_dt   = "2026-03-06T18:00:00Z"


bins_df = get_ifcb_bins_datetime_filtered(base_url, dataset, start_dt, end_dt)
bins = bins_df["pid"].tolist()


print(f"Found {len(bins)} bins between {start_dt} and {end_dt}")
print(bins[:5])
# Out:
# Found 50 bins between 2026-03-04T21:00:00Z and 2026-03-06T18:00:00Z
# ['D20260304T213619_IFCB149', 'D20260304T230920_IFCB149', 'D20260304T235551_IFCB149', 'D20260305T004222_IFCB149', 'D20260305T012853_IFCB149']

# %%
print(bins_df.columns.tolist())
print(bins_df.head())
# Out:
# ['dataset', 'pid', 'sample_time', 'ifcb', 'ml_analyzed', 'latitude', 'longitude', 'depth', 'cruise', 'cast', 'niskin', 'sample_type', 'n_images', 'comment_summary', 'trigger_selection', 'skip']
#            dataset                       pid               sample_time  ifcb  \
# 0  hablab_AlexLowV  D20260304T213619_IFCB149 2026-03-04 21:36:19+00:00   149
# 1  hablab_AlexLowV  D20260304T230920_IFCB149 2026-03-04 23:09:20+00:00   149
# 2  hablab_AlexLowV  D20260304T235551_IFCB149 2026-03-04 23:55:51+00:00   149
# 3  hablab_AlexLowV  D20260305T004222_IFCB149 2026-03-05 00:42:22+00:00   149
# 4  hablab_AlexLowV  D20260305T012853_IFCB149 2026-03-05 01:28:53+00:00   149
#
#    ml_analyzed  latitude  longitude  depth  cruise  cast  niskin  sample_type  \
# 0     2.041506       NaN        NaN    NaN     NaN   NaN     NaN  Alternative
# 1     2.147015       NaN        NaN    NaN     NaN   NaN     NaN  Alternative
# 2     2.074453       NaN        NaN    NaN     NaN   NaN     NaN  Alternative
# 3     2.068321       NaN        NaN    NaN     NaN   NaN     NaN  Alternative
# 4     2.122359       NaN        NaN    NaN     NaN   NaN     NaN  Alternative
#
#    n_images  comment_summary  trigger_selection  skip
# 0      8608              NaN                  2     0
# 1      8294              NaN                  2     0
# 2      8505              NaN                  2     0
# 3      8539              NaN                  2     0
# 4      8342              NaN                  2     0

# %% [markdown]
# ### with PID list now download ADC, HDR, and Class lists
#
# loops through PID list and hits dashboard API for adc, hdr and class lists

# %%
from pathlib import Path
from typing import Dict, List

def download_file(url: str,
                  dest_path: Path,
                  overwrite: bool = False,
                  timeout: int = 30) -> bool:
    if dest_path.exists() and not overwrite:
        print(f"[skip] {dest_path} already exists")
        return True

    try:
        r = requests.get(url, timeout=timeout)
    except Exception as e:
        print(f"[error] GET {url} failed: {e}")
        return False

    if r.status_code == 200:
        dest_path.parent.mkdir(parents=True, exist_ok=True)
        dest_path.write_bytes(r.content)
        print(f"[ok]   {url} -> {dest_path}")
        return True
    elif r.status_code == 404:
        print(f"[404]  {url} not found")
        return False
    else:
        print(f"[{r.status_code}] {url} (no download)")
        return False


def download_ifcb_bins(base_url: str,
                       dataset: str,
                       pids: List[str],
                       dest_dir: str,
                       download_adc: bool = True,
                       download_hdr: bool = True,
                       download_class: bool = True,
                       class_suffix: str = "_class_vNone.csv",
                       overwrite: bool = False,
                       timeout: int = 30) -> Dict[str, Dict[str, Path]]:
    base_url = base_url.rstrip("/")
    dest_root = Path(dest_dir)
    files_downloaded: Dict[str, Dict[str, Path]] = {}

    for pid in pids:
        print(f"\n=== {pid} ===")
        pid_results: Dict[str, Path] = {}

        if download_adc:
            adc_url = f"{base_url}/{dataset}/{pid}.adc"
            adc_path = dest_root / dataset / f"{pid}.adc"
            if download_file(adc_url, adc_path, overwrite=overwrite, timeout=timeout):
                pid_results["adc"] = adc_path

        if download_hdr:
            hdr_url = f"{base_url}/{dataset}/{pid}.hdr"
            hdr_path = dest_root / dataset / f"{pid}.hdr"
            if download_file(hdr_url, hdr_path, overwrite=overwrite, timeout=timeout):
                pid_results["hdr"] = hdr_path

        if download_class:
            class_filename = f"{pid}{class_suffix}"
            class_url = f"{base_url}/{dataset}/{class_filename}"
            class_path = dest_root / dataset / class_filename
            if download_file(class_url, class_path, overwrite=overwrite, timeout=timeout):
                pid_results["class"] = class_path

        if pid_results:
            files_downloaded[pid] = pid_results

    return files_downloaded

# %% [markdown]
# # example usage

# %%
## example usage

# 1) Filter bins by datetime
bins_df = get_ifcb_bins_datetime_filtered(
    base_url = "https://habon-ifcb.whoi.edu",
    dataset="hablab_AlexLowV",
    start = start_dt,
    end   = end_dt
)
bins = bins_df["pid"].tolist()

# 2) Download files only for those bins
files = download_ifcb_bins(
    base_url = "https://habon-ifcb.whoi.edu",
    dataset="hablab_AlexLowV",
    pids=bins,
    dest_dir="../../IFCBData/dilExp/Alex/",
    class_suffix="_class_scores.csv",  # change if nauset uses a different suffix -- just go to the dashboard and copy class link as text and see what it looks like if unsure
)
# Out:
# === D20260304T213619_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260304T213619_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260304T213619_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260304T213619_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260304T213619_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260304T213619_IFCB149_class_scores.csv not found
#
# === D20260304T230920_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260304T230920_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260304T230920_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260304T230920_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260304T230920_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260304T230920_IFCB149_class_scores.csv not found
#
# === D20260304T235551_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260304T235551_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260304T235551_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260304T235551_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260304T235551_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260304T235551_IFCB149_class_scores.csv not found
#
# === D20260305T004222_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T004222_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T004222_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T004222_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T004222_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T004222_IFCB149_class_scores.csv not found
#
# === D20260305T012853_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T012853_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T012853_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T012853_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T012853_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T012853_IFCB149_class_scores.csv not found
#
# === D20260305T021524_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T021524_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T021524_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T021524_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T021524_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T021524_IFCB149_class_scores.csv not found
#
# === D20260305T030155_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T030155_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T030155_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T030155_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T030155_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T030155_IFCB149_class_scores.csv not found
#
# === D20260305T034826_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T034826_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T034826_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T034826_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T034826_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T034826_IFCB149_class_scores.csv not found
#
# === D20260305T043457_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T043457_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T043457_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T043457_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T043457_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T043457_IFCB149_class_scores.csv not found
#
# === D20260305T052127_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T052127_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T052127_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T052127_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260305T052127_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305T052127_IFCB149_class_scores.csv not found
#
# === D20260305T060758_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260305
IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T043644_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T043644_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T043644_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T043644_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T043644_IFCB149_class_scores.csv not found
#
# === D20260306T052315_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T052315_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T052315_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T052315_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T052315_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T052315_IFCB149_class_scores.csv not found
#
# === D20260306T060946_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T060946_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T060946_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T060946_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T060946_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T060946_IFCB149_class_scores.csv not found
#
# === D20260306T065617_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T065617_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T065617_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T065617_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T065617_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T065617_IFCB149_class_scores.csv not found
#
# === D20260306T074248_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T074248_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T074248_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T074248_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T074248_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T074248_IFCB149_class_scores.csv not found
#
# === D20260306T082919_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T082919_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T082919_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T082919_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T082919_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T082919_IFCB149_class_scores.csv not found
#
# === D20260306T091550_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T091550_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T091550_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T091550_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T091550_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T091550_IFCB149_class_scores.csv not found
#
# === D20260306T100220_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T100220_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T100220_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T100220_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T100220_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T100220_IFCB149_class_scores.csv not found
#
# === D20260306T104851_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T104851_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T104851_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T104851_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T104851_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T104851_IFCB149_class_scores.csv not found
#
# === D20260306T113521_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T113521_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T113521_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T113521_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T113521_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T113521_IFCB149_class_scores.csv not found
#
# === D20260306T160001_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T160001_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T160001_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T160001_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T160001_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T160001_IFCB149_class_scores.csv not found
#
# === D20260306T164632_IFCB149 ===
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T164632_IFCB149.adc -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T164632_IFCB149.adc
# [ok]   https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T164632_IFCB149.hdr -> ../../IFCBData/dilExp/Alex/hablab_AlexLowV/D20260306T164632_IFCB149.hdr
# [404]  https://habon-ifcb.whoi.edu/hablab_AlexLowV/D20260306T164632_IFCB149_class_scores.csv not found

# %%
## Or use your own prebuilt PID bins list 
## import json pid list if you have it saved already, otherwise use the above functions to pull bins and save as json for future use

import json

with open("../../IFCBData/PIDLists/mvco_2025.json", "r") as f:
    bins = json.load(f)

if not isinstance(bins, list):
    raise ValueError("PID JSON should be a list of PID strings.")

bins = [str(pid) for pid in bins]
print(bins[:5])
print(f"Loaded {len(bins)} bins from JSON file")
# Out:
# ['D20250907T120626_IFCB127', 'D20250908T000732_IFCB127', 'D20250908T120329_IFCB127', 'D20250909T000436_IFCB127', 'D20250909T120036_IFCB127']
# Loaded 153 bins from JSON file

# %%
### Be sure to check base url and dataset is matched with PID source
## Strange below does not seem to work will retirn to this at some point -- for now can use built in functions
files = download_ifcb_bins(
    base_url = "https://habon-ifcb.whoi.edu",
    dataset="mvco",  # change if needed by dataset
    pids=bins, 
    dest_dir="../../IFCBData/mvco2025/", 
    class_suffix="_class_scores.csv",  # change if needed by dataset
    overwrite= False, # Set to false to skip downloading files that already exist locally, true to redownload and overwrite
    timeout=30, # time to wait for server response before giving up on download, in seconds
    download_adc=True, 
    download_hdr=True,
    download_class=True,
 )
# Out:
# === D20250907T120626_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20250907T120626_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20250907T120626_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20250907T120626_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20250907T120626_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20250907T120626_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20250907T120626_IFCB127_class_scores.csv
#
# === D20250908T000732_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20250908T000732_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20250908T000732_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20250908T000732_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20250908T000732_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20250908T000732_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20250908T000732_IFCB127_class_scores.csv
#
# === D20250908T120329_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20250908T120329_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20250908T120329_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20250908T120329_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20250908T120329_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20250908T120329_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20
IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251117T120451_IFCB127_class_scores.csv
#
# === D20251118T000505_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251118T000505_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251118T000505_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251118T000505_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251118T000505_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251118T000505_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251118T000505_IFCB127_class_scores.csv
#
# === D20251118T120130_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251118T120130_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251118T120130_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251118T120130_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251118T120130_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251118T120130_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251118T120130_IFCB127_class_scores.csv
#
# === D20251119T000139_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251119T000139_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251119T000139_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251119T000139_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251119T000139_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251119T000139_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251119T000139_IFCB127_class_scores.csv
#
# === D20251119T122020_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251119T122020_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251119T122020_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251119T122020_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251119T122020_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251119T122020_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251119T122020_IFCB127_class_scores.csv
#
# === D20251120T002026_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251120T002026_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251120T002026_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251120T002026_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251120T002026_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251120T002026_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251120T002026_IFCB127_class_scores.csv
#
# === D20251120T121642_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251120T121642_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251120T121642_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251120T121642_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251120T121642_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251120T121642_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251120T121642_IFCB127_class_scores.csv
#
# === D20251121T001644_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251121T001644_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251121T001644_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251121T001644_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251121T001644_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251121T001644_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251121T001644_IFCB127_class_scores.csv
#
# === D20251121T121257_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251121T121257_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251121T121257_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251121T121257_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251121T121257_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251121T121257_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251121T121257_IFCB127_class_scores.csv
#
# === D20251122T001259_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251122T001259_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251122T001259_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251122T001259_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251122T001259_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251122T001259_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251122T001259_IFCB127_class_scores.csv
#
# === D20251122T123521_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251122T123521_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251122T123521_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251122T123521_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251122T123521_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251122T123521_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251122T123521_IFCB127_class_scores.csv
#
# === D20251123T000911_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251123T000911_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251123T000911_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251123T000911_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251123T000911_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251123T000911_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251123T000911_IFCB127_class_scores.csv
#
# === D20251123T120912_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251123T120912_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251123T120912_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251123T120912_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251123T120912_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251123T120912_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251123T120912_IFCB127_class_scores.csv
#
# === D20251124T000523_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251124T000523_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251124T000523_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251124T000523_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251124T000523_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251124T000523_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251124T000523_IFCB127_class_scores.csv
#
# === D20251124T120524_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251124T120524_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251124T120524_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251124T120524_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251124T120524_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251124T120524_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251124T120524_IFCB127_class_scores.csv
#
# === D20251125T000140_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251125T000140_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251125T000140_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251125T000140_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251125T000140_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251125T000140_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251125T000140_IFCB127_class_scores.csv
#
# === D20251125T120140_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251125T120140_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251125T120140_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251125T120140_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251125T120140_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251125T120140_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251125T120140_IFCB127_class_scores.csv
#
# === D20251126T002018_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251126T002018_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251126T002018_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251126T002018_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251126T002018_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251126T002018_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251126T002018_IFCB127_class_scores.csv
#
# === D20251126T121933_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251126T121933_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251126T121933_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251126T121933_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251126T121933_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251126T121933_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251126T121933_IFCB127_class_scores.csv
#
# === D20251127T001548_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251127T001548_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251127T001548_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251127T001548_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251127T001548_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251127T001548_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251127T001548_IFCB127_class_scores.csv
#
# === D20251127T121529_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251127T121529_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251127T121529_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251127T121529_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251127T121529_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251127T121529_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251127T121529_IFCB127_class_scores.csv
#
# === D20251128T001153_IFCB127 ===
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251128T001153_IFCB127.adc -> ../../IFCBData/mvco2025/mvco/D20251128T001153_IFCB127.adc
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251128T001153_IFCB127.hdr -> ../../IFCBData/mvco2025/mvco/D20251128T001153_IFCB127.hdr
# [ok]   https://habon-ifcb.whoi.edu/mvco/D20251128T001153_IFCB127_class_scores.csv -> ../../IFCBData/mvco2025/mvco/D20251128T001153_IFCB127_class_scores.csv
