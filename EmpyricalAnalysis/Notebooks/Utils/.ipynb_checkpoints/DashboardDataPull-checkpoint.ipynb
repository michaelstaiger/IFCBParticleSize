# %% [markdown]
# ## Building a plugin to pull data directly from dashbaord
#
# ### generate_ifcb_pids
# this creates a list of pids that it will references as it pulls data files from a set date time range
# input the time of interest you want to look at
#
# I can not get the api to work for filtering so hacky way to get around is just make a list of all the pids and then filter that to just the times you want so that is what get_ifcb_bins_datetime_filtered does
#
# ### Hit API for required files
# download_file -- helper function that pulls api and saves without overwriting if the file already exists
# download_ifcb_bins - used download_file to loop over PID list for specified file types -- probably easy to add other metadata stuff

# %%
## Does not currently work the API does not use standard date time or I have something wrong so this just makes a list of all PIDs in a dataset

import requests
import pandas as pd
from datetime import datetime

def get_ifcb_bins_datetime(base_url: str,
                           dataset: str,
                           start: str,
                           end: str) -> pd.DataFrame:
    """
    Query the IFCB dashboard API to get a list of bins (PIDs)
    for a given dataset and datetime range.

    Parameters
    ----------
    base_url : str
        e.g. "https://habon-ifcb.whoi.edu"
    dataset : str
        e.g. "dagm01"
    start, end : str
        ISO-like datetime strings, e.g. "2023-12-14T09:00:00".

    Returns
    -------
    DataFrame with at least a 'pid' column.
    """
    base_url = base_url.rstrip("/")
    url = (
        f"{base_url}/api/list_bins"
        f"?dataset={dataset}"
        f"&start_datetime={start}"
        f"&end_datetime={end}"
    )

    r = requests.get(url)
    r.raise_for_status()
    data = r.json()["data"]
    bins_df = pd.DataFrame(data)
    return bins_df
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
base_url = "https://habon-ifcb.whoi.edu"
dataset = "nauset"

start_dt = "2024-04-02T00:00:00"
end_dt   = "2024-04-02T23:00:00"

bins_df = get_ifcb_bins_datetime(base_url, dataset, start_dt, end_dt)
bins = bins_df["pid"].tolist()

print(f"Found {len(bins)} bins between {start_dt} and {end_dt}")
print(bins[:5])
# Out:
# Found 52455 bins between 2024-04-02T00:00:00 and 2024-04-02T23:00:00
# ['D20120318T192302_IFCB000', 'D20120318T192302_IFCB010', 'D20120318T220052_IFCB000', 'D20120318T220052_IFCB010', 'D20120319T135125_IFCB010']

# %% [markdown]
# ### Above does not seem to actual fiulter by time which is anyoing I should look for/ ask around how API works to see if we can get it to work but simple work around is to just filter this list off all pids to the times I want
#
# #### that is what is below use for now

# %%
import requests
import pandas as pd

def get_ifcb_bins_datetime_filtered(base_url: str,
                                    dataset: str,
                                    start: str,
                                    end: str) -> pd.DataFrame:
    """
    Get all bins for a dataset from /api/list_bins, then filter by sample_time
    between 'start' and 'end' (inclusive).

    Parameters
    ----------
    base_url : e.g. "https://habon-ifcb.whoi.edu"
    dataset  : e.g. "nauset"
    start, end : ISO-like datetime strings, e.g. "2025-06-25T09:00:00Z"

    Returns
    -------
    DataFrame with only bins in the requested time window.
    """
    base_url = base_url.rstrip("/")
    url = f"{base_url}/api/list_bins?dataset={dataset}"

    r = requests.get(url)
    r.raise_for_status()
    data = r.json()["data"]

    df = pd.DataFrame(data)

    # Adjust this column name if needed, but on HABON it should be 'sample_time'
    df["sample_time"] = pd.to_datetime(df["sample_time"])

    start_dt = pd.to_datetime(start)
    end_dt   = pd.to_datetime(end)

    mask = (df["sample_time"] >= start_dt) & (df["sample_time"] <= end_dt)
    return df.loc[mask].copy()

# %%
## example usage ##

###URL OPTIONS
## PERCY: http://percy.whoi.edu:8000
## HABON: https://habon-ifcb.whoi.edu

base_url = "https://habon-ifcb.whoi.edu"
dataset = "radbot_ios"

start_dt = "2023-07-03T00:00:00Z"
end_dt   = "2023-07-05T12:00:00Z"


bins_df = get_ifcb_bins_datetime_filtered(base_url, dataset, start_dt, end_dt)
bins = bins_df["pid"].tolist()

print(f"Found {len(bins)} bins between {start_dt} and {end_dt}")
print(bins[:5])
# Out:
# Found 99 bins between 2023-07-03T00:00:00Z and 2023-07-05T12:00:00Z
# ['D20230703T014826_IFCB110', 'D20230703T021155_IFCB110', 'D20230703T023525_IFCB110', 'D20230703T030213_IFCB110', 'D20230703T032543_IFCB110']

# %% [markdown]
# ### with PID list now download ADC, HDR, and Class lists
#
# loops through PID list and hits dashboard API for adc, hdr and class lists

# %%
from pathlib import Path
from typing import Dict, List

def download_file(url: str,
                  dest_path: Path,
                  overwrite: bool = False,
                  timeout: int = 30) -> bool:
    if dest_path.exists() and not overwrite:
        print(f"[skip] {dest_path} already exists")
        return True

    try:
        r = requests.get(url, timeout=timeout)
    except Exception as e:
        print(f"[error] GET {url} failed: {e}")
        return False

    if r.status_code == 200:
        dest_path.parent.mkdir(parents=True, exist_ok=True)
        dest_path.write_bytes(r.content)
        print(f"[ok]   {url} -> {dest_path}")
        return True
    elif r.status_code == 404:
        print(f"[404]  {url} not found")
        return False
    else:
        print(f"[{r.status_code}] {url} (no download)")
        return False


def download_ifcb_bins(base_url: str,
                       dataset: str,
                       pids: List[str],
                       dest_dir: str,
                       download_adc: bool = True,
                       download_hdr: bool = True,
                       download_class: bool = True,
                       class_suffix: str = "_class_vNone.csv",
                       overwrite: bool = False,
                       timeout: int = 30) -> Dict[str, Dict[str, Path]]:
    base_url = base_url.rstrip("/")
    dest_root = Path(dest_dir)
    files_downloaded: Dict[str, Dict[str, Path]] = {}

    for pid in pids:
        print(f"\n=== {pid} ===")
        pid_results: Dict[str, Path] = {}

        if download_adc:
            adc_url = f"{base_url}/{dataset}/{pid}.adc"
            adc_path = dest_root / dataset / f"{pid}.adc"
            if download_file(adc_url, adc_path, overwrite=overwrite, timeout=timeout):
                pid_results["adc"] = adc_path

        if download_hdr:
            hdr_url = f"{base_url}/{dataset}/{pid}.hdr"
            hdr_path = dest_root / dataset / f"{pid}.hdr"
            if download_file(hdr_url, hdr_path, overwrite=overwrite, timeout=timeout):
                pid_results["hdr"] = hdr_path

        if download_class:
            class_filename = f"{pid}{class_suffix}"
            class_url = f"{base_url}/{dataset}/{class_filename}"
            class_path = dest_root / dataset / class_filename
            if download_file(class_url, class_path, overwrite=overwrite, timeout=timeout):
                pid_results["class"] = class_path

        if pid_results:
            files_downloaded[pid] = pid_results

    return files_downloaded

# %% [markdown]
# # example usage

# %%
## example usage

# 1) Filter bins by datetime
bins_df = get_ifcb_bins_datetime_filtered(
    base_url = "https://habon-ifcb.whoi.edu",
    dataset="radbot_ios",
    start = start_dt,
    end   = end_dt
)
bins = bins_df["pid"].tolist()

# 2) Download files only for those bins
files = download_ifcb_bins(
    base_url = "https://habon-ifcb.whoi.edu",
    dataset="radbot_ios",
    pids=bins,
    dest_dir="../../IFCBData/SeaTrac/",
    class_suffix="_class_scores.csv",  # change if nauset uses a different suffix -- just go to the dashboard and copy class link as text and see what it looks like if unsure
)
# Out:
# === D20230703T014826_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T014826_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T014826_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T014826_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T014826_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T014826_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T014826_IFCB110_class_scores.csv
#
# === D20230703T021155_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T021155_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T021155_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T021155_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T021155_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T021155_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T021155_IFCB110_class_scores.csv
#
# === D20230703T023525_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T023525_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T023525_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T023525_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T023525_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T023525_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T023525_IFCB110_class_scores.csv
#
# === D20230703T030213_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T030213_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T030213_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T030213_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T030213_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T030213_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T030213_IFCB110_class_scores.csv
#
# === D20230703T032543_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T032543_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T032543_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T032543_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T032543_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T032543_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T032543_IFCB110_class_scores.csv
#
# === D20230703T034912_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T034912_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T034912_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T034912_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T034912_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T034912_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T034912_IFCB110_class_scores.csv
#
# === D20230703T041600_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T041600_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T041600_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T041600_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T041600_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T041600_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T041600_IFCB110_class_scores.csv
#
# === D20230703T043930_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T043930_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T043930_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T043930_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T043930_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T043930_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T043930_IFCB110_class_scores.csv
#
# === D20230703T050259_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T050259_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T050259_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T050259_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T050259_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T050259_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T050259_IFCB110_class_scores.csv
#
# === D20230703T052947_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T052947_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T052947_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T052947_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T052947_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T052947_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T052947_IFCB110_class_scores.csv
#
# === D20230703T055317_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T055317_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T055317_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T055317_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T055317_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T055317_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T055317_IFCB110_class_scores.csv
#
# === D20230703T061646_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T061646_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T061646_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T061646_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T061646_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T061646_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T061646_IFCB110_class_scores.csv
#
# === D20230703T064334_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T064334_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T064334_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T064334_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T064334_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T064334_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T064334_IFCB110_class_scores.csv
#
# === D20230703T070704_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T070704_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T070704_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T070704_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T070704_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T070704_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T070704_IFCB110_class_scores.csv
#
# === D20230703T073034_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T073034_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T073034_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T073034_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T073034_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T073034_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T073034_IFCB110_class_scores.csv
#
# === D20230703T075722_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T075722_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T075722_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T075722_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T075722_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T075722_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T075722_IFCB110_class_scores.csv
#
# === D20230703T082051_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T082051_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T082051_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T082051_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T082051_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T082051_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T082051_IFCB110_class_scores.csv
#
# === D20230703T084421_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T084421_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T084421_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T084421_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T084421_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T084421_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T084421_IFCB110_class_scores.csv
#
# === D20230703T091109_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T091109_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T091109_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T091109_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T091109_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T091109_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T091109_IFCB110_class_scores.csv
#
# === D20230703T093438_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T093438_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T093438_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T093438_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T093438_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T093438_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T093438_IFCB110_class_scores.csv
#
# === D20230703T095808_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T095808_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T095808_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T095808_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T095808_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T095808_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T095808_IFCB110_class_scores.csv
#
# === D20230703T102456_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T102456_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T102456_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T102456_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T102456_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T102456_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T102456_IFCB110_class_scores.csv
#
# === D20230703T104826_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T104826_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T104826_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T104826_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T104826_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T104826_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T104826_IFCB110_class_scores.csv
#
# === D20230703T111155_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T111155_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T111155_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T111155_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T111155_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T111155_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T111155_IFCB110_class_scores.csv
#
# === D20230703T113843_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T113843_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T113843_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T113843_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T113843_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T113843_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T113843_IFCB110_class_scores.csv
#
# === D20230703T120213_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T120213_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T120213_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T120213_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T120213_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T120213_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T120213_IFCB110_class_scores.csv
#
# === D20230703T122543_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T122543_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T122543_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T122543_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T122543_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T122543_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T122543_IFCB110_class_scores.csv
#
# === D20230703T125230_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T125230_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T125230_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T125230_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T125230_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T125230_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T125230_IFCB110_class_scores.csv
#
# === D20230703T131600_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T131600_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T131600_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T131600_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T131600_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T131600_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T131600_IFCB110_class_scores.csv
#
# === D20230703T133930_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T133930_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T133930_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T133930_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T133930_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T133930_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T133930_IFCB110_class_scores.csv
#
# === D20230703T140617_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T140617_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T140617_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T140617_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T140617_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T140617_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T140617_IFCB110_class_scores.csv
#
# === D20230703T142947_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T142947_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T142947_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T142947_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T142947_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T142947_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T142947_IFCB110_class_scores.csv
#
# === D20230703T145317_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T145317_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T145317_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T145317_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T145317_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T145317_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T145317_IFCB110_class_scores.csv
#
# === D20230703T152005_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T152005_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T152005_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T152005_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T152005_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T152005_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T152005_IFCB110_class_scores.csv
#
# === D20230703T154334_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T154334_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T154334_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T154334_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T154334_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T154334_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T154334_IFCB110_class_scores.csv
#
# === D20230703T160704_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T160704_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T160704_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T160704_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T160704_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T160704_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T160704_IFCB110_class_scores.csv
#
# === D20230703T163352_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T163352_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T163352_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T163352_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T163352_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T163352_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T163352_IFCB110_class_scores.csv
#
# === D20230703T165721_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T165721_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T165721_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T165721_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T165721_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T165721_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T165721_IFCB110_class_scores.csv
#
# === D20230703T190518_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T190518_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T190518_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T190518_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T190518_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T190518_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T190518_IFCB110_class_scores.csv
#
# === D20230703T192847_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T192847_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T192847_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T192847_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T192847_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T192847_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T192847_IFCB110_class_scores.csv
#
# === D20230703T195217_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T195217_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T195217_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T195217_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T195217_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T195217_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T195217_IFCB110_class_scores.csv
#
# === D20230703T201905_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T201905_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T201905_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T201905_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T201905_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T201905_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T201905_IFCB110_class_scores.csv
#
# === D20230703T204234_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T204234_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T204234_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T204234_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T204234_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T204234_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T204234_IFCB110_class_scores.csv
#
# === D20230703T210604_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T210604_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T210604_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T210604_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T210604_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T210604_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T210604_IFCB110_class_scores.csv
#
# === D20230703T213252_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T213252_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T213252_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T213252_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T213252_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T213252_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T213252_IFCB110_class_scores.csv
#
# === D20230703T215622_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T215622_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T215622_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T215622_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T215622_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T215622_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T215622_IFCB110_class_scores.csv
#
# === D20230703T221951_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T221951_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T221951_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T221951_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T221951_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T221951_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T221951_IFCB110_class_scores.csv
#
# === D20230703T224639_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T224639_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T224639_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T224639_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T224639_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T224639_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T224639_IFCB110_class_scores.csv
#
# === D20230703T231009_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T231009_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T231009_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T231009_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T231009_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T231009_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T231009_IFCB110_class_scores.csv
#
# === D20230703T233338_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T233338_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T233338_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T233338_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T233338_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230703T233338_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230703T233338_IFCB110_class_scores.csv
#
# === D20230704T000026_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T000026_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T000026_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T000026_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T000026_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T000026_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T000026_IFCB110_class_scores.csv
#
# === D20230704T002356_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T002356_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T002356_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T002356_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T002356_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T002356_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T002356_IFCB110_class_scores.csv
#
# === D20230704T004726_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T004726_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T004726_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T004726_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T004726_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T004726_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T004726_IFCB110_class_scores.csv
#
# === D20230704T011413_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T011413_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T011413_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T011413_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T011413_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T011413_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T011413_IFCB110_class_scores.csv
#
# === D20230704T013743_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T013743_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T013743_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T013743_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T013743_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T013743_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T013743_IFCB110_class_scores.csv
#
# === D20230704T020113_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T020113_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T020113_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T020113_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T020113_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T020113_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T020113_IFCB110_class_scores.csv
#
# === D20230704T022801_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T022801_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T022801_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T022801_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T022801_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T022801_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T022801_IFCB110_class_scores.csv
#
# === D20230704T025130_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T025130_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T025130_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T025130_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T025130_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T025130_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T025130_IFCB110_class_scores.csv
#
# === D20230704T031500_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T031500_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T031500_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T031500_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T031500_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T031500_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T031500_IFCB110_class_scores.csv
#
# === D20230704T034148_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T034148_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T034148_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T034148_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T034148_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T034148_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T034148_IFCB110_class_scores.csv
#
# === D20230704T040517_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T040517_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T040517_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T040517_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T040517_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T040517_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T040517_IFCB110_class_scores.csv
#
# === D20230704T042847_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T042847_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T042847_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T042847_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T042847_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T042847_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T042847_IFCB110_class_scores.csv
#
# === D20230704T045535_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T045535_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T045535_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T045535_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T045535_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T045535_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T045535_IFCB110_class_scores.csv
#
# === D20230704T051905_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T051905_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T051905_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T051905_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T051905_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T051905_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T051905_IFCB110_class_scores.csv
#
# === D20230704T054234_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T054234_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T054234_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T054234_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T054234_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T054234_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T054234_IFCB110_class_scores.csv
#
# === D20230704T060922_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T060922_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T060922_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T060922_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T060922_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T060922_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T060922_IFCB110_class_scores.csv
#
# === D20230704T063252_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T063252_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T063252_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T063252_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T063252_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T063252_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T063252_IFCB110_class_scores.csv
#
# === D20230704T065621_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T065621_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T065621_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T065621_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T065621_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T065621_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T065621_IFCB110_class_scores.csv
#
# === D20230704T072309_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T072309_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T072309_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T072309_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T072309_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T072309_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T072309_IFCB110_class_scores.csv
#
# === D20230704T074639_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T074639_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T074639_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T074639_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T074639_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T074639_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T074639_IFCB110_class_scores.csv
#
# === D20230704T081009_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T081009_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T081009_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T081009_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T081009_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T081009_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T081009_IFCB110_class_scores.csv
#
# === D20230704T083656_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T083656_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T083656_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T083656_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T083656_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T083656_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T083656_IFCB110_class_scores.csv
#
# === D20230704T090026_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T090026_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T090026_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T090026_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T090026_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T090026_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T090026_IFCB110_class_scores.csv
#
# === D20230704T092356_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T092356_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T092356_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T092356_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T092356_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T092356_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T092356_IFCB110_class_scores.csv
#
# === D20230704T095044_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T095044_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T095044_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T095044_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T095044_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T095044_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T095044_IFCB110_class_scores.csv
#
# === D20230704T101413_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T101413_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T101413_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T101413_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T101413_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T101413_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T101413_IFCB110_class_scores.csv
#
# === D20230704T103743_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T103743_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T103743_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T103743_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T103743_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T103743_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T103743_IFCB110_class_scores.csv
#
# === D20230704T110431_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T110431_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T110431_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T110431_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T110431_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T110431_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T110431_IFCB110_class_scores.csv
#
# === D20230704T112800_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T112800_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T112800_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T112800_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T112800_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T112800_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T112800_IFCB110_class_scores.csv
#
# === D20230704T115130_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T115130_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T115130_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T115130_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T115130_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T115130_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T115130_IFCB110_class_scores.csv
#
# === D20230704T121818_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T121818_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T121818_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T121818_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T121818_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T121818_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T121818_IFCB110_class_scores.csv
#
# === D20230704T124147_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T124147_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T124147_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T124147_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T124147_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T124147_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T124147_IFCB110_class_scores.csv
#
# === D20230704T130517_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T130517_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T130517_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T130517_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T130517_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T130517_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T130517_IFCB110_class_scores.csv
#
# === D20230704T133205_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T133205_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T133205_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T133205_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T133205_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T133205_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T133205_IFCB110_class_scores.csv
#
# === D20230704T135535_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T135535_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T135535_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T135535_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T135535_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T135535_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T135535_IFCB110_class_scores.csv
#
# === D20230704T141904_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T141904_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T141904_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T141904_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T141904_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T141904_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T141904_IFCB110_class_scores.csv
#
# === D20230704T144552_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T144552_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T144552_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T144552_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T144552_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T144552_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T144552_IFCB110_class_scores.csv
#
# === D20230704T150922_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T150922_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T150922_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T150922_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T150922_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T150922_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T150922_IFCB110_class_scores.csv
#
# === D20230704T153252_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T153252_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T153252_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T153252_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T153252_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T153252_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T153252_IFCB110_class_scores.csv
#
# === D20230704T155939_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T155939_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T155939_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T155939_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T155939_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T155939_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T155939_IFCB110_class_scores.csv
#
# === D20230704T162309_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T162309_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T162309_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T162309_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T162309_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T162309_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T162309_IFCB110_class_scores.csv
#
# === D20230704T164639_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T164639_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T164639_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T164639_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T164639_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T164639_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T164639_IFCB110_class_scores.csv
#
# === D20230704T171327_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T171327_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T171327_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T171327_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T171327_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T171327_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T171327_IFCB110_class_scores.csv
#
# === D20230704T173656_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T173656_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T173656_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T173656_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T173656_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T173656_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T173656_IFCB110_class_scores.csv
#
# === D20230704T180026_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T180026_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T180026_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T180026_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T180026_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T180026_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T180026_IFCB110_class_scores.csv
#
# === D20230704T182714_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T182714_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T182714_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T182714_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T182714_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T182714_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T182714_IFCB110_class_scores.csv
#
# === D20230704T185043_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T185043_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T185043_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T185043_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T185043_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T185043_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T185043_IFCB110_class_scores.csv
#
# === D20230704T193704_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T193704_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T193704_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T193704_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T193704_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230704T193704_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230704T193704_IFCB110_class_scores.csv
#
# === D20230705T025434_IFCB110 ===
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230705T025434_IFCB110.adc -> ../../IFCBData/SeaTrac/radbot_ios/D20230705T025434_IFCB110.adc
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230705T025434_IFCB110.hdr -> ../../IFCBData/SeaTrac/radbot_ios/D20230705T025434_IFCB110.hdr
# [ok]   https://habon-ifcb.whoi.edu/radbot_ios/D20230705T025434_IFCB110_class_scores.csv -> ../../IFCBData/SeaTrac/radbot_ios/D20230705T025434_IFCB110_class_scores.csv
