# %%
from pathlib import Path
import json
import sys

import pandas as pd

analysis_root = Path("/Users/michaelstaiger/Desktop/gitRepos/IFCBParticleSize/EmpyricalAnalysis/Notebooks/")
if str(analysis_root) not in sys.path:
    sys.path.insert(0, str(analysis_root))

from PiecewiseInhibitProbability import get_ifcb_pids_by_daily_times
from ifcb_summary_streaming import summarize_bins_streaming
