# %% [markdown]
# ## Spawn dataset data ingest and processing
# Here I want to explore data from nours dan ward samples and see if the settling behavior is observed and if it varries depening on development stage of the larvae
#
# I will try to create a standardized data flow so can be reperposed in the future maybe with evies clam bloom stuff and other future exp sets
#
# to import and merge the data sets I used notebooks from the utils folder DashboardDataPull and IngestIFCBData

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from typing import Optional
import os

# %% [markdown]
# # Zygotes

# %%
data_dir = "../IFCBData/spawn/zygotes/merged/" #can add further levels if goiong for zygote
fig_dir = "../Figs/spawn/"

# %%
### lets just look at rois over time vs linear for one and then can change to loop over all the things inthe merged directry

# %%
merged_df = pd.read_csv("../IFCBData/spawn/zygotes/merged/D20240501T182329_IFCB145_adc_only.csv")

# %%
plt.plot(merged_df['RunTime'], merged_df['RoiNumber'], linewidth=2)
plt.xlabel("Time (s)")
plt.ylabel("Rois")
#plt.ylim(0, 1)
plt.title("Rois Over Time Zygotes")
# Get first and last points
x_start, y_start = merged_df["RunTime"].iloc[0], merged_df["RoiNumber"].iloc[0]
x_end, y_end     = merged_df["RunTime"].iloc[-1], merged_df["RoiNumber"].iloc[-1]
# Add straight reference line (first → last point)
plt.plot([x_start, x_end], [y_start, y_end],
        linestyle="--", color="gray", label="linear reference")
plt.show()

# %%
## to loop and beyond!

# %%
# Each with there own linear?

# %%
data_dir = data_dir

plt.figure(figsize=(10, 6))

for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    df = pd.read_csv(os.path.join(data_dir, fname))

    # Force numeric (prevents weird string sorting / plotting issues)
    df["RunTime"] = pd.to_numeric(df["RunTime"], errors="coerce")
    df["RoiNumber"] = pd.to_numeric(df["RoiNumber"], errors="coerce")
    df = df.dropna(subset=["RunTime", "RoiNumber"]).sort_values("RunTime")

    if len(df) < 2:
        continue

    x_start, y_start = df["RunTime"].iloc[0],  df["RoiNumber"].iloc[0]
    x_end,   y_end   = df["RunTime"].iloc[-1], df["RoiNumber"].iloc[-1]

    # Plot main curve and capture its color
    line, = plt.plot(df["RunTime"], df["RoiNumber"], linewidth=1.5, alpha=0.7)

    # Plot per-file reference line in the SAME color
    plt.plot([x_start, x_end], [y_start, y_end],
             linestyle="--", linewidth=1.2, alpha=0.9,
             color=line.get_color())

plt.xlabel("Time (s)")
plt.ylabel("Rois")
plt.title("ROI Over time vs Linear for Zygotes")
plt.tight_layout()
plt.savefig(
     os.path.join(fig_dir, "ZygoteRoiVsLinear.png"),
)
plt.show()

# %%
## normalized ? rois/time vs time

# %%
data_dir = data_dir

plt.figure(figsize=(10, 6))

first_x = first_y = None
last_x = last_y = None

for fname in sorted(os.listdir(data_dir)):
    if not fname.endswith(".csv"):
        continue

    df = pd.read_csv(os.path.join(data_dir, fname))

    # Ensure sorted by time
    df = df.sort_values("RunTime")

    # Compute differences
    dt = df["RunTime"].diff()
    droi = df["RoiNumber"].diff()

    # ROI rate (ROIs per second)
    roi_rate = droi / dt

    # Time associated with rate (midpoint)
    time_mid = df["RunTime"].iloc[1:].values

    # Drop first NaN
    roi_rate = roi_rate.iloc[1:]

    plt.plot(time_mid, roi_rate, alpha=0.5, linewidth=1)


    
    # Track global endpoints for reference line
    if first_x is None:
        first_x = time_mid[0]
        first_y = roi_rate.iloc[0]

    last_x = time_mid[-1]
    last_y = roi_rate.iloc[-1]

# Linear reference line across all data
plt.plot(
    [first_x, last_x],
    [first_y, last_y],
    linestyle="--",
    color="black",
    linewidth=2,
    label="Linear reference"
)

plt.xlabel("Time (s)")
plt.ylabel("ROIs per second")
plt.title("ROI Rate vs Time (Normalized)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
### somewhat intersting just tells you that average rois per second goes down over time from ~5 to 1

# %% [markdown]
# #### Kind of interesting this means this looks like the more rois you have the more off linear you are so there is a higher rate of rois being missed

# %% [markdown]
# ## Look time exploration

# %%
## from ExploringLookTimeandClass basic function for looping over data

# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from pathlib import Path
# from typing import Optional

def _extract_adc_headers(hdr_path: Path):
    with open(hdr_path, 'r') as f:
        for line in f:
            if line.startswith("ADCFileFormat:"):
                return [h.strip() for h in line.split(":", 1)[1].split(",")]
    raise ValueError(f"ADCFileFormat not found in header file: {hdr_path}")

def _load_adc_for_timeline(adc_path: Path, hdr_path: Path) -> pd.DataFrame:
    headers = _extract_adc_headers(hdr_path)
    df = pd.read_csv(adc_path, header=None)
    df.columns = headers[:df.shape[1]]
    # ensure numeric
    df['RunTime'] = pd.to_numeric(df['RunTime'], errors='coerce')
    df['InhibitTime'] = pd.to_numeric(df['InhibitTime'], errors='coerce')
    df = df.dropna(subset=['RunTime','InhibitTime']).sort_values('RunTime').reset_index(drop=True)
    return df

def plot_directory_timelines_time_inhibit_first(
    data_dir: str,
    abs_tol: float = 1e-6,
    save_path: Optional[str] = None,
    max_files: Optional[int] = None,
):
    """
    Scan a directory for *.hdr / *.adc pairs and plot a single figure with
    a horizontal 'state' strip per sample (red=inhibited first, blue=running).
    Returns a summary DataFrame with totals per sample.

    Parameters
    ----------
    data_dir : str
        Directory to scan recursively.
    abs_tol : float
        Small threshold to treat tiny ΔInhibit as zero (jitter).
    save_path : str or None
        If set, save the figure here (e.g., 'stacked_timelines.png').
    max_files : int or None
        Limit number of samples to plot (useful for quick previews).

    Returns
    -------
    summary_df : pd.DataFrame with columns:
        ['Sample', 'total_elapsed_s', 'total_running_s', 'total_inhibited_s',
         'final_runtime_s', 'final_inhibittime_s']
    """
    data_path = Path(data_dir)
    records = []  # (sample_name, df)

    # find hdr/adc pairs
    for hdr in sorted(data_path.rglob("*.hdr")):
        adc = hdr.with_suffix(".adc")
        if not adc.exists():
            continue
        try:
            df = _load_adc_for_timeline(adc, hdr)
            if len(df) >= 2:
                records.append((hdr.stem, df))
        except Exception as e:
            print(f"Skipping {hdr.stem}: {e}")

        if max_files and len(records) >= max_files:
            break

    if not records:
        print("No valid ADC/HDR pairs found.")
        return pd.DataFrame(columns=[
            'Sample','total_elapsed_s','total_running_s','total_inhibited_s',
            'final_runtime_s','final_inhibittime_s'
        ])

    # Determine global x-limit (max RunTime across samples)
    xmax = max(float(df['RunTime'].max()) for _, df in records)

    # One axes, stack rows by y offset (0..N-1)
    fig, ax = plt.subplots(figsize=(14, 1.1 * len(records) + 1))
    ytick_locs, ytick_labels = [], []

    summaries = []

    for row_idx, (name, df) in enumerate(records):
        line_spacing = 0.2  # smaller = closer lines, default was 1.0
        y0 = float(row_idx) * line_spacing

        # deltas
        dt = df['RunTime'].diff().to_numpy()
        dI = df['InhibitTime'].diff().to_numpy()

        # jitter & clamp
        dI = np.where(dI > abs_tol, dI, 0.0)
        dt = np.where(np.isfinite(dt), dt, 0.0)
        dI = np.where(np.isfinite(dI), dI, 0.0)
        dt = np.where(dt < 0, 0.0, dt)
        dI = np.clip(dI, 0.0, dt)

        x = df['RunTime'].to_numpy()
        total_inhib = 0.0
        total_run = 0.0

        # draw: inhibited (red) first, then running (blue)
        for i in range(1, len(df)):
            x0 = float(x[i-1]); x1 = float(x[i])
            if not np.isfinite(x0) or not np.isfinite(x1) or x1 <= x0:
                continue
            di = float(dI[i])
            dr = float(dt[i] - di)

            cur = x0
            if di > 0:
                ax.plot([cur, cur+di], [y0, y0], color='red', linewidth=20, solid_capstyle='butt')
                cur += di
                total_inhib += di
            if dr > 0:
                ax.plot([cur, x1], [y0, y0], color='blue', linewidth=20, solid_capstyle='butt')
                total_run += dr

        ytick_locs.append(y0)
        ytick_labels.append(name)

        summaries.append({
            'Sample': name,
            'total_elapsed_s': total_run + total_inhib,
            'total_running_s': total_run,
            'total_inhibited_s': total_inhib,
            'final_runtime_s': float(df['RunTime'].iloc[-1]),
            'final_inhibittime_s': float(df['InhibitTime'].iloc[-1]),
        })

    # Style axes
    ax.set_xlim(0, xmax)
    ax.set_ylim(-line_spacing, len(records) * line_spacing)
    ax.set_yticks(ytick_locs)
    ax.set_yticklabels(ytick_labels, fontsize=9)
    ax.set_xlabel("Run Time (s)")
    ax.set_title("Instrument State Over Time (red = inhibited first, blue = running/waiting)")
    ax.grid(False)
    for sp in ['right','top']:
        ax.spines[sp].set_visible(False)

    # # Make a tiny legend line
    # leg_x0, leg_y = xmax * 0.02, len(records) - 0.8
    # ax.plot([leg_x0, leg_x0 + xmax*0.06], [leg_y, leg_y], color='red', linewidth=6)
    # ax.text(leg_x0 + xmax*0.07, leg_y, "Inhibited", va='center', fontsize=9)
    # leg_y2 = leg_y - 0.5
    # ax.plot([leg_x0, leg_x0 + xmax*0.06], [leg_y2, leg_y2], color='blue', linewidth=6)
    # ax.text(leg_x0 + xmax*0.07, leg_y2, "Running/Waiting", va='center', fontsize=9)

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=300)
        print(f"Saved stacked timeline to: {save_path}")
    plt.show()

    summary_df = pd.DataFrame(summaries).sort_values('Sample').reset_index(drop=True)
    return summary_df

# %%
summary_dir = plot_directory_timelines_time_inhibit_first(
    data_dir= "../IFCBData/spawn/zygotes/",
    save_path= "../Figs/spawn/zygotes_looktime.png"
)
print(summary_dir)
# Out:
# Saved stacked timeline to: ../Figs/spawn/zygotes_looktime.png
#                      Sample  total_elapsed_s  total_running_s  \
# 0  D20240501T182329_IFCB145      1200.866747       821.690697
# 1  D20240501T185545_IFCB145      1200.820054       876.066406
# 2  D20240501T200201_IFCB145      1200.928255       682.816994
#
#    total_inhibited_s  final_runtime_s  final_inhibittime_s
# 0         379.176050      1200.947639           379.187222
# 1         324.753648      1200.894444           324.764375
# 2         518.111261      1201.000556           518.121875

# %% [markdown]
# ### Now lets see if we can do concentration estimates over time
# This is trickier because there are not any annotations on this data set but it is basically a monoculutre so i am just going to look at rois per volume over time

# %%
# import os
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# data_dir = "/path/to/your/merged_csv_directory"
# fig_dir  = "/path/to/your/figures"   # optional
# os.makedirs(fig_dir, exist_ok=True)  # optional

plt.figure(figsize=(10, 6))

for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    df = pd.read_csv(os.path.join(data_dir, fname))

    # Make sure required columns are numeric
    for col in ["RunTime", "RoiNumber", "VolumeAnalyzed"]:
        df[col] = pd.to_numeric(df[col], errors="coerce")

    # Clean + sort
    df = df.dropna(subset=["RunTime", "RoiNumber", "VolumeAnalyzed"]).sort_values("RunTime")
    if len(df) < 2:
        continue

    # Avoid divide-by-zero
    df = df[df["VolumeAnalyzed"] > 0]
    if len(df) < 2:
        continue

    y = df["RoiNumber"] / df["VolumeAnalyzed"]

    plt.plot(df["RunTime"], y, linewidth=1.5, alpha=0.6)

plt.xlabel("Time (s)")
plt.ylabel("RoiNumber / VolumeAnalyzed (ml)")
plt.title("Zygote ROI per ml vs Time")
plt.tight_layout()

# Optional save
outpath = os.path.join(fig_dir, "ZygoteROIpermlvsTime.png")
plt.savefig(outpath, dpi=300, bbox_inches="tight")

plt.show()

print("Saved:", outpath)
# Out:
# Saved: ../Figs/spawn/ZygoteROIpermlvsTime.png

# %% [markdown]
# #### I think this would be alot more powerful if annotated there is some detritus that hangs out not sure exactly what we are looking at here I could probably run model on this set and see what we get a fun side project for another day

# %% [markdown]
# #### going to be difficult to separate out classes for now but what if we just separate by some arbitrary size class for now that would probably be quickish but for that i need some veliger / d shaped

# %% [markdown]
# # Dshaped Veliger

# %%
data_dir = "../IFCBData/spawn/DShape_Veliger/mixedbutlots/merged/" 
fig_dir = "../Figs/spawn/"

# %%
## compute roi area to sort by since I do not have class files

# %%
for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    path = os.path.join(data_dir, fname)
    df = pd.read_csv(path)

    # Safety: ensure required columns exist
    if not {"RoiHeight", "RoiWidth"}.issubset(df.columns):
        print(f"Skipping {fname}: missing RoiHeight or RoiWidth")
        continue

    # Force numeric (prevents silent string multiplication)
    df["RoiHeight"] = pd.to_numeric(df["RoiHeight"], errors="coerce")
    df["RoiWidth"]  = pd.to_numeric(df["RoiWidth"],  errors="coerce")

    # Add / overwrite RoiArea
    df["RoiArea"] = df["RoiHeight"] * df["RoiWidth"]

    # Write back to SAME file
    df.to_csv(path, index=False)

print("All CSV files updated in place with RoiArea.")
# Out:
# All CSV files updated in place with RoiArea.

# %%
## histogram of all areas

# %%
all_roi_area = []

for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    df = pd.read_csv(os.path.join(data_dir, fname))

    if "RoiArea" not in df.columns:
        print(f"Skipping {fname}: RoiArea not found")
        continue

    roi_area = pd.to_numeric(df["RoiArea"], errors="coerce")

    # Drop bad values
    roi_area = roi_area[(roi_area > 0) & np.isfinite(roi_area)]

    all_roi_area.append(roi_area.values)

# Combine into one array
all_roi_area = np.concatenate(all_roi_area)

# =====================
# Plot histogram
# =====================
plt.figure(figsize=(8, 6))

plt.hist(
    all_roi_area,
    bins=100,
    log=True,        # strongly recommended for ROI sizes
    alpha=0.8
)

## Verticle lines ##
# some arbitrary areas that I chose to mostly encapsulate what I think is the actual cells we care about and exclude the rest
thresholds = [70000, 240000] 

for t in thresholds:
    plt.axvline(
        t,
        color="red",
        linestyle="--",
        linewidth=1.5,
        alpha=0.8
    )


plt.xlabel("RoiArea (pixels²)")
plt.ylabel("Count")
plt.title("Histogram of RoiArea (All Files)")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### looking at this plus some example images most dshaped to veliger size larvae are roughly 300-400 pixel squares or around 111,000 area which is roughly that first peak so I am going to subset by that area and then look at how the different size classes behave
#
# Code for subsetting 'SizeClass' variable
# 1 = <70000
#
# 2 =  70000<roiarea<180000
#
# 3 = >180000
#
# for the  mixed group i used 240000 as the upper bound, this will need to be better organized maybe just make a readme somewhere because now I am looking at them as they increase in age over the course of the experiment and they get bigger so maybe they will behave differently

# %%
for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    path = os.path.join(data_dir, fname)
    df = pd.read_csv(path)

    if "RoiArea" not in df.columns:
        print(f"Skipping {fname}: RoiArea not found")
        continue

    # Ensure numeric
    df["RoiArea"] = pd.to_numeric(df["RoiArea"], errors="coerce")

    # Initialize with NaN (good practice)
    df["SizeClass"] = np.nan

    # Apply rules will depend on what the size classes are
    df.loc[df["RoiArea"] < 70000, "SizeClass"] = 1
    df.loc[(df["RoiArea"] >= 70000) & (df["RoiArea"] <= 240000), "SizeClass"] = 2 ##### change these as needed 
    df.loc[df["RoiArea"] > 240000, "SizeClass"] = 3

    # Optional: convert to integer nullable type
    df["SizeClass"] = df["SizeClass"].astype("Int64")

    # Write back to SAME file
    df.to_csv(path, index=False)

print("All CSV files updated with SizeClass column.")
# Out:
# All CSV files updated with SizeClass column.

# %%
print(testdf.head)
# Out:
# <bound method NDFrame.head of       RoiNumber      ADCtime      RunTime  InhibitTime  InhibitTimeDiff  \
# 0             2     4.682563     4.703785     0.081597         0.000000
# 1             4     5.114797     5.136326     0.247472         0.165875
# 2             5     5.309669     5.328919     0.327309         0.079837
# 3             6     5.397764     5.421066     0.411717         0.084408
# 4             7     5.544854     5.565503     0.493440         0.081723
# ...         ...          ...          ...          ...              ...
# 7153       8264  1200.045260  1200.070417   669.368611         0.081319
# 7154       8265  1200.315748  1200.339722   669.450139         0.081528
# 7155       8266  1200.521914  1200.547639   669.532639         0.082500
# 7156       8267  1200.696855  1200.722361   669.615833         0.083194
# 7157       8270  1201.636786  1201.662083   669.766944         0.151111
#
#       VolumeAnalyzed  RoiHeight  RoiWidth  RoiX  RoiY  RoiArea  SizeClass
# ...

# %%
testsubdf = testdf[testdf["SizeClass"] == 2].copy()  #create new subset of just relevant ones to test some stuff on
print(testsubdf.head)
# Out:
# <bound method NDFrame.head of       RoiNumber      ADCtime      RunTime  InhibitTime  InhibitTimeDiff  \
# 7            10     5.997167     6.021552     0.745250         0.085399
# 76           89    16.747652    16.769221     7.018014         0.082109
# 124         143    23.612392    23.635679    11.328707         0.084223
# 262         301    43.228593    43.249900    24.343813         0.082480
# 264         303    43.338595    43.361493    24.427383         0.000000
# ...         ...          ...          ...          ...              ...
# 7135       8237  1193.828512  1193.855139   667.192292         0.256944
# 7139       8245  1195.381151  1195.406389   667.875069         0.248750
# 7144       8254  1197.253429  1197.280833   668.538819         0.167153
# 7146       8256  1198.537437  1198.562639   668.700694         0.081597
# 7155       8266  1200.521914  1200.547639   669.532639         0.082500
#
#       VolumeAnalyzed  RoiHeight  RoiWidth  RoiX  RoiY  RoiArea  SizeClass
# ...

# %%
plt.plot(testsubdf['RunTime'], testsubdf['RoiNumber'], linewidth=2)
plt.xlabel("Time (s)")
plt.ylabel("Rois")
#plt.ylim(0, 1)
plt.title("Rois Over Time DShaped Veliger")
# Get first and last points
x_start, y_start = testsubdf["RunTime"].iloc[0], testsubdf["RoiNumber"].iloc[0]
x_end, y_end     = testsubdf["RunTime"].iloc[-1], testsubdf["RoiNumber"].iloc[-1]
# Add straight reference line (first → last point)
plt.plot([x_start, x_end], [y_start, y_end],
        linestyle="--", color="gray", label="linear reference")
plt.show()

# %% [markdown]
# ## loop over data dir to create conc over time plots
#
# subset to SizeClass 2
#
# make a new “counting up from 1” column (cumulative count within that subset)
#
# compute concentration = (subset cumulative count) / (VolumeAnalyzed)
#
# plot concentration vs RunTime
#
# repeat for all CSVs in data_dir

# %%
# import os
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# data_dir = "/path/to/your/csv_directory"

plt.figure(figsize=(10, 6))

for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    path = os.path.join(data_dir, fname)
    df = pd.read_csv(path)

    # ---- required columns check ----
    required = {"RunTime", "VolumeAnalyzed", "SizeClass"}
    if not required.issubset(df.columns):
        print(f"Skipping {fname}: missing one of {required}")
        continue

    # ---- numeric + clean + sort ----
    df["RunTime"] = pd.to_numeric(df["RunTime"], errors="coerce")
    df["VolumeAnalyzed"] = pd.to_numeric(df["VolumeAnalyzed"], errors="coerce")

    # SizeClass may be Int64; coerce safely
    df["SizeClass"] = pd.to_numeric(df["SizeClass"], errors="coerce")

    df = df.dropna(subset=["RunTime", "VolumeAnalyzed", "SizeClass"]).sort_values("RunTime")
    if len(df) < 2:
        continue

    # ---- subset to size class 2 ----
    sub = df[df["SizeClass"] == 2].copy()
    if sub.empty:
        continue

    # ---- build a clean 1..N count just for this subset ----
    sub["ObsCount_SC2"] = np.arange(1, len(sub) + 1)

    # ---- determine whether VolumeAnalyzed is cumulative or incremental ----
    # If it is non-decreasing, treat as cumulative; otherwise use cumulative sum
    vol = sub["VolumeAnalyzed"].values
    is_non_decreasing = np.all(np.diff(vol) >= 0)

    if is_non_decreasing:
        sub["CumVol"] = sub["VolumeAnalyzed"]
    else:
        sub["CumVol"] = sub["VolumeAnalyzed"].cumsum()

    # Avoid divide-by-zero / negative volumes
    sub = sub[sub["CumVol"] > 0]
    if len(sub) < 2:
        continue

    # ---- concentration estimate: count / cumulative volume ----
    sub["Conc_SC2"] = sub["ObsCount_SC2"] / sub["CumVol"]

    # ---- plot ----
    plt.plot(sub["RunTime"], sub["Conc_SC2"], linewidth=1.5, alpha=0.6)

plt.xlabel("RunTime (s)")
plt.ylabel("Estimated concentration (SC2 count / cumulative VolumeAnalyzed)")
plt.title("SizeClass 2 concentration vs RunTime (All Files)")
plt.tight_layout()
plt.savefig("../Figs/spawn/DShapeSizeSubSetConcOverTime.png")
plt.show()

# %%
## look time for shits and giggles

# %%
summary_dir = plot_directory_timelines_time_inhibit_first(
    data_dir= "../IFCBData/spawn/DShape_Veliger/",
    #save_path= "../Figs/spawn/zygotes_looktime.png"
)
print(summary_dir)
# Out:
#                      Sample  total_elapsed_s  total_running_s  \
# 0  D20240507T200128_IFCB145      1201.589833       531.833299
# 1  D20240507T205306_IFCB145      1201.616122       616.378494
# 2  D20240507T211652_IFCB145      1201.751209       725.776020
#
#    total_inhibited_s  final_runtime_s  final_inhibittime_s
# 0         669.756534      1201.662083           669.766944
# 1         585.237628      1201.688611           585.248056
# 2         475.975189      1201.824444           475.985625

# %%
# import os
# import pandas as pd
# import matplotlib.pyplot as plt

# data_dir = "/path/to/your/csv_directory"

plt.figure(figsize=(10, 6))

for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    df = pd.read_csv(os.path.join(data_dir, fname))

    # Required columns check
    if not {"RunTime", "RoiArea"}.issubset(df.columns):
        print(f"Skipping {fname}: missing RunTime or RoiArea")
        continue

    # Ensure numeric + clean + sort
    df["RunTime"] = pd.to_numeric(df["RunTime"], errors="coerce")
    df["RoiArea"] = pd.to_numeric(df["RoiArea"], errors="coerce")

    df = df.dropna(subset=["RunTime", "RoiArea"]).sort_values("RunTime")

        # ---- subset to SizeClass 2 ---- 
    #df = df[df["SizeClass"] == 2]  # comment out this line if you want all the data or change the subset number 
    if len(df) < 2:
        continue

    plt.scatter(
        df["RunTime"],
        df["RoiArea"],
        linewidth=1,
        alpha=0.5
    )

plt.xlabel("RunTime (s)")
plt.ylabel("RoiArea (pixels²)")
plt.title("RoiArea vs RunTime (All Files)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Why the Heck Not we ball with all of the data and see what it looks like

# %%
data_dir = "../IFCBData/spawn/All/spawn/merged/"
fig_dir = "../Figs/spawn/"

# %%
for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    path = os.path.join(data_dir, fname)
    df = pd.read_csv(path)

    # Safety: ensure required columns exist
    if not {"RoiHeight", "RoiWidth"}.issubset(df.columns):
        print(f"Skipping {fname}: missing RoiHeight or RoiWidth")
        continue

    # Force numeric (prevents silent string multiplication)
    df["RoiHeight"] = pd.to_numeric(df["RoiHeight"], errors="coerce")
    df["RoiWidth"]  = pd.to_numeric(df["RoiWidth"],  errors="coerce")

    # Add / overwrite RoiArea
    df["RoiArea"] = df["RoiHeight"] * df["RoiWidth"]

    # Write back to SAME file
    df.to_csv(path, index=False)

print("All CSV files updated in place with RoiArea.")
# Out:
# All CSV files updated in place with RoiArea.

# %%
all_roi_area = []

for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    df = pd.read_csv(os.path.join(data_dir, fname))

    if "RoiArea" not in df.columns:
        print(f"Skipping {fname}: RoiArea not found")
        continue

    roi_area = pd.to_numeric(df["RoiArea"], errors="coerce")

    # Drop bad values
    roi_area = roi_area[(roi_area > 0) & np.isfinite(roi_area)]

    all_roi_area.append(roi_area.values)

# Combine into one array
all_roi_area = np.concatenate(all_roi_area)

# =====================
# Plot histogram
# =====================
plt.figure(figsize=(8, 6))

plt.hist(
    all_roi_area,
    bins=100,
    log=True,        # strongly recommended for ROI sizes
    alpha=0.8
)

## Verticle lines ##
# some arbitrary areas that I chose to mostly encapsulate what I think is the actual cells we care about and exclude the rest
thresholds = [70000, 240000] 

for t in thresholds:
    plt.axvline(
        t,
        color="red",
        linestyle="--",
        linewidth=1.5,
        alpha=0.8
    )


plt.xlabel("RoiArea (pixels²)")
plt.ylabel("Count")
plt.title("Histogram of RoiArea (All Files)")
plt.tight_layout()
plt.show()

# %%
for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    path = os.path.join(data_dir, fname)
    df = pd.read_csv(path)

    if "RoiArea" not in df.columns:
        print(f"Skipping {fname}: RoiArea not found")
        continue

    # Ensure numeric
    df["RoiArea"] = pd.to_numeric(df["RoiArea"], errors="coerce")

    # Initialize with NaN (good practice)
    df["SizeClass"] = np.nan

    # Apply rules will depend on what the size classes are
    df.loc[df["RoiArea"] < 70000, "SizeClass"] = 1
    df.loc[(df["RoiArea"] >= 70000) & (df["RoiArea"] <= 240000), "SizeClass"] = 2 ##### change these as needed 
    df.loc[df["RoiArea"] > 240000, "SizeClass"] = 3

    # Optional: convert to integer nullable type
    df["SizeClass"] = df["SizeClass"].astype("Int64")

    # Write back to SAME file
    df.to_csv(path, index=False)

print("All CSV files updated with SizeClass column.")
# Out:
# All CSV files updated with SizeClass column.

# %%
# import os
# import pandas as pd
# import matplotlib.pyplot as plt

# data_dir = "/path/to/your/csv_directory"

plt.figure(figsize=(10, 6))

for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    df = pd.read_csv(os.path.join(data_dir, fname))

    # Required columns check
    if not {"RunTime", "RoiArea"}.issubset(df.columns):
        print(f"Skipping {fname}: missing RunTime or RoiArea")
        continue

    # Ensure numeric + clean + sort
    df["RunTime"] = pd.to_numeric(df["RunTime"], errors="coerce")
    df["RoiArea"] = pd.to_numeric(df["RoiArea"], errors="coerce")

    df = df.dropna(subset=["RunTime", "RoiArea"]).sort_values("RunTime")

        # ---- subset to SizeClass 2 ---- 
    #df = df[df["SizeClass"] == 2]  # comment out this line if you want all the data or change the subset number 
    if len(df) < 2:
        continue

    plt.scatter(
        df["RunTime"],
        df["RoiArea"],
        linewidth=1,
        alpha=0.5
    )

plt.xlabel("RunTime (s)")
plt.ylabel("RoiArea (pixels²)")
plt.title("RoiArea vs RunTime (All Files)")
plt.tight_layout()
plt.show()

# %%
# import os
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# data_dir = "/path/to/your/csv_directory"

plt.figure(figsize=(10, 6))

for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    path = os.path.join(data_dir, fname)
    df = pd.read_csv(path)

    # ---- required columns check ----
    required = {"RunTime", "VolumeAnalyzed", "SizeClass"}
    if not required.issubset(df.columns):
        print(f"Skipping {fname}: missing one of {required}")
        continue

    # ---- numeric + clean + sort ----
    df["RunTime"] = pd.to_numeric(df["RunTime"], errors="coerce")
    df["VolumeAnalyzed"] = pd.to_numeric(df["VolumeAnalyzed"], errors="coerce")

    # SizeClass may be Int64; coerce safely
    df["SizeClass"] = pd.to_numeric(df["SizeClass"], errors="coerce")

    df = df.dropna(subset=["RunTime", "VolumeAnalyzed", "SizeClass"]).sort_values("RunTime")
    if len(df) < 2:
        continue

    # ---- subset to size class 2 ----
    sub = df[df["SizeClass"] == 2].copy()
    if sub.empty:
        continue

    # ---- build a clean 1..N count just for this subset ----
    sub["ObsCount_SC2"] = np.arange(1, len(sub) + 1)

    # ---- determine whether VolumeAnalyzed is cumulative or incremental ----
    # If it is non-decreasing, treat as cumulative; otherwise use cumulative sum
    vol = sub["VolumeAnalyzed"].values
    is_non_decreasing = np.all(np.diff(vol) >= 0)

    if is_non_decreasing:
        sub["CumVol"] = sub["VolumeAnalyzed"]
    else:
        sub["CumVol"] = sub["VolumeAnalyzed"].cumsum()

    # Avoid divide-by-zero / negative volumes
    sub = sub[sub["CumVol"] > 0]
    if len(sub) < 2:
        continue

    # ---- concentration estimate: count / cumulative volume ----
    sub["Conc_SC2"] = sub["ObsCount_SC2"] / sub["CumVol"]

    # ---- plot ----
    plt.plot(sub["RunTime"], sub["Conc_SC2"], linewidth=1.5, alpha=0.6)

plt.xlabel("RunTime (s)")
plt.ylabel("Estimated concentration (SC2 count / cumulative VolumeAnalyzed)")
plt.title("SizeClass 2 concentration vs RunTime (All Files)")
plt.tight_layout()
plt.savefig("../Figs/spawn/all2024filesconcovertime.png")
plt.show()

# %% [markdown]
# ### it looks like files with higher concentrations have more settling -- unsurprising but maybe it is shouldnt they settle at the same rate so maybe there is some particle particle interaction
# I want to just get the files names for the ones with the most settling and see what they are like on the dashboard

# %%
# import os
# import numpy as np
# import pandas as pd

# data_dir = "/path/to/your/csv_directory"
threshold = 1000

files_exceeding_1000 = []

for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    df = pd.read_csv(os.path.join(data_dir, fname))

    required = {"RunTime", "VolumeAnalyzed", "SizeClass"}
    if not required.issubset(df.columns):
        continue

    df["RunTime"] = pd.to_numeric(df["RunTime"], errors="coerce")
    df["VolumeAnalyzed"] = pd.to_numeric(df["VolumeAnalyzed"], errors="coerce")
    df["SizeClass"] = pd.to_numeric(df["SizeClass"], errors="coerce")

    df = df.dropna(subset=["RunTime", "VolumeAnalyzed", "SizeClass"]).sort_values("RunTime")
    if len(df) < 2:
        continue

    # ---- subset to size class 2 ----
    sub = df[df["SizeClass"] == 2]
    if sub.empty:
        continue

    # ---- SC2 cumulative count ----
    obs_count = np.arange(1, len(sub) + 1)

    # ---- cumulative volume ----
    vol = sub["VolumeAnalyzed"].values
    cum_vol = vol if np.all(np.diff(vol) >= 0) else np.cumsum(vol)

    # ---- concentration ----
    conc_sc2 = obs_count / cum_vol

    # ---- threshold check ----
    if (conc_sc2 > threshold).any():
        files_exceeding_1000.append(fname)

print(files_exceeding_1000)
# Out:
# ['D20240507T192151_IFCB145_adc_only.csv', 'D20240515T202005_IFCB145_adc_only.csv', 'D20240517T203508_IFCB145_adc_only.csv', 'D20240517T205856_IFCB145_adc_only.csv']

# %% [markdown]
# #### looking at them on the dashboard
#
# D20240507T192151_IFCB145_adc_only.csv', -- dinophysis culture testing ifcb
# D20240515T202005_IFCB145_adc_only.csv', -- lots 17 pages of cells, mostly d shaped without velum all lighter grey colored not dark black
# D20240517T203508_IFCB145_adc_only.csv', -- also lots 19 pages same grey color more velum but plenty without
# D20240517T205856_IFCB145_adc_only.csv', --same as above comes from same sample
#
# What is intersting here is that the samples from the 15th are 14 days old and at the end of their planktonic stage where as the larvae from 17th are 4 years old so this likely does nor have to do with size or developmental stage and has more to do with particle particle interactions that might be causing higher settling rates

# %% [markdown]
# ### Trying something else I wonder what the rois per second look like over time like are we seeing more at the start probably not but lets see

# %%
# import os
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

#data_dir = "../IFCBData/spawn/DShape_Veliger/mixedbutlots/merged/"
bin_size_sec = 10  # <-- change this (e.g., 1, 2, 5, 10)

plt.figure(figsize=(10, 6))

for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    df = pd.read_csv(os.path.join(data_dir, fname))

    required = {"RunTime", "SizeClass"}
    if not required.issubset(df.columns):
        print(f"Skipping {fname}: missing RunTime or SizeClass")
        continue

    # numeric + clean
    df["RunTime"] = pd.to_numeric(df["RunTime"], errors="coerce")
    df["SizeClass"] = pd.to_numeric(df["SizeClass"], errors="coerce")
    df = df.dropna(subset=["RunTime", "SizeClass"]).sort_values("RunTime")
    if len(df) < 2:
        continue

    # subset to SizeClass 2
    sub2 = df[df["SizeClass"] == 2].copy()
    if sub2.empty:
        continue

    # normalize time to start at 0 for each file (recommended for overlaying)
    t = sub2["RunTime"].values
    t = t - t[0]

    # bin times: 0..bin_size.. etc
    bin_index = (t // bin_size_sec).astype(int)

    # count ROIs per bin
    counts = pd.Series(bin_index).value_counts().sort_index()

    # build a complete set of bins (so missing bins show as 0)
    n_bins = int(np.floor(t.max() / bin_size_sec)) + 1
    counts = counts.reindex(range(n_bins), fill_value=0)

    # x axis as bin center time
    x = (counts.index.values * bin_size_sec) + (bin_size_sec / 2.0)

    # rois per second
    rois_per_sec = counts.values / bin_size_sec


    # ## Optional Smoothing ###
    # smooth_window_bins = 30   # e.g. 5 bins = 5 seconds if bin_size_sec = 1
    
    # rois_per_sec_smooth = (
    #     pd.Series(rois_per_sec)
    #         .rolling(window=smooth_window_bins, center=True, min_periods=1)
    #         .mean()
    #         .values
    # )


    plt.plot(x, rois_per_sec, linewidth=1.2, alpha=0.6)

plt.xlabel("RunTime (s) (per-file normalized to start at 0)")
plt.ylabel(f"ROIs/sec (SizeClass 2, bin={bin_size_sec}s)")
plt.title("SizeClass 2 ROIs/sec vs RunTime (All Files)")
plt.tight_layout()
plt.show()

# %%
# import os
# import numpy as np
# import pandas as pd

# data_dir = "/path/to/your/csv_directory"

bin_size_sec = 10       # time bin size (seconds)
smooth_window_bins = 5    # smoothing window in BINS (so 5 bins = 5 sec if bin_size_sec=1)
threshold = 4         # <-- ROIs/sec threshold you choose

files_over_threshold = []

for fname in sorted(os.listdir(data_dir)):
    if not fname.lower().endswith(".csv"):
        continue

    df = pd.read_csv(os.path.join(data_dir, fname))

    required = {"RunTime", "SizeClass"}
    if not required.issubset(df.columns):
        continue

    df["RunTime"] = pd.to_numeric(df["RunTime"], errors="coerce")
    df["SizeClass"] = pd.to_numeric(df["SizeClass"], errors="coerce")
    df = df.dropna(subset=["RunTime", "SizeClass"]).sort_values("RunTime")

    sub2 = df[df["SizeClass"] == 2]
    if sub2.empty:
        continue

    # per-file time normalization (matches your earlier approach)
    t = sub2["RunTime"].values
    t = t - t[0]

    # bin and count events
    bin_index = (t // bin_size_sec).astype(int)
    counts = pd.Series(bin_index).value_counts().sort_index()

    n_bins = int(np.floor(t.max() / bin_size_sec)) + 1
    if n_bins < 2:
        continue

    counts = counts.reindex(range(n_bins), fill_value=0)

    rois_per_sec = counts.values / bin_size_sec

    # # Optional smoothing (rolling mean)
    # rois_per_sec_smooth = (
    #     pd.Series(rois_per_sec)
    #     .rolling(window=smooth_window_bins, center=True, min_periods=1)
    #     .mean()
    #     .values
    # )

    # threshold check
    if (rois_per_sec_smooth > threshold).any():
        files_over_threshold.append(fname)

print(files_over_threshold)
# Out:
# ['D20240501T182329_IFCB145_adc_only.csv', 'D20240501T185545_IFCB145_adc_only.csv', 'D20240501T200201_IFCB145_adc_only.csv', 'D20240501T204013_IFCB145_adc_only.csv', 'D20240505T224724_IFCB145_adc_only.csv', 'D20240505T230949_IFCB145_adc_only.csv', 'D20240505T233338_IFCB145_adc_only.csv', 'D20240507T191000_IFCB145_adc_only.csv', 'D20240507T192151_IFCB145_adc_only.csv', 'D20240507T192956_IFCB145_adc_only.csv', 'D20240507T193742_IFCB145_adc_only.csv', 'D20240507T200128_IFCB145_adc_only.csv', 'D20240507T205306_IFCB145_adc_only.csv', 'D20240507T211652_IFCB145_adc_only.csv', 'D20240508T215317_IFCB145_adc_only.csv', 'D20240509T130156_IFCB145_adc_only.csv', 'D20240509T132541_IFCB145_adc_only.csv', 'D20240509T134927_IFCB145_adc_only.csv', 'D20240513T135642_IFCB145_adc_only.csv', 'D20240513T142027_IFCB145_adc_only.csv', 'D20240513T144413_IFCB145_adc_only.csv', 'D20240513T150800_IFCB145_adc_only.csv', 'D20240513T153725_IFCB145_adc_only.csv', 'D20240513T160111_IFCB145_adc_only.csv', 'D20240513T16
# ...
