# %%
## Exploring summary stats to think about best ways to visuallize and compare data sets

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../IFCBData/summaries/mdiblsum.csv")

# %%
print(df.head())
print(df.columns.tolist())
# Out:
#    roi0  roi1  roi2  roi3  roi4  roi5  roi6  roi7    vfinal  \
# 0  2494  5773   118     6     0     0     0     0  2.033933
# 1   993  6723   158     3     0     0     0     0  2.333128
# 2  1675  5381   122     3     0     0     0     0  2.557271
# 3  2839  4473    94     3     0     0     0     0  2.481247
# 4  1195  5366   112     3     0     0     0     0  2.745597
#
#    inhibittime_final    looktime                       pid
# 0         689.792986  488.143958  D20210818T162700_IFCB152
# 1         640.740764  559.950764  D20210818T200600_IFCB152
# 2         586.989931  613.745069  D20210819T020119_IFCB152
# 3         605.153819  595.499375  D20210819T082020_IFCB152
# 4         541.644444  658.943194  D20210819T141539_IFCB152
# ['roi0', 'roi1', 'roi2', 'roi3', 'roi4', 'roi5', 'roi6', 'roi7', 'vfinal', 'inhibittime_final', 'looktime', 'pid']

# %%
## Split pid into new date time and ifcb columns
# Split on "_"
split_cols = df["pid"].str.split("_", expand=True)

df["datetime_str"] = split_cols[0]
df["ifcb"] = split_cols[1]
df["datetime"] = pd.to_datetime(
    df["datetime_str"].str[1:],  # remove "D"
    format="%Y%m%dT%H%M%S"
)

## Sort by datetime
df = df.sort_values("datetime")

# %%
print(df.head())
print(df.columns.tolist())
# Out:
#    roi0  roi1  roi2  roi3  roi4  roi5  roi6  roi7    vfinal  \
# 0  2494  5773   118     6     0     0     0     0  2.033933
# 1   993  6723   158     3     0     0     0     0  2.333128
# 2  1675  5381   122     3     0     0     0     0  2.557271
# 3  2839  4473    94     3     0     0     0     0  2.481247
# 4  1195  5366   112     3     0     0     0     0  2.745597
#
#    inhibittime_final    looktime                       pid      datetime_str  \
# 0         689.792986  488.143958  D20210818T162700_IFCB152  D20210818T162700
# 1         640.740764  559.950764  D20210818T200600_IFCB152  D20210818T200600
# 2         586.989931  613.745069  D20210819T020119_IFCB152  D20210819T020119
# 3         605.153819  595.499375  D20210819T082020_IFCB152  D20210819T082020
# 4         541.644444  658.943194  D20210819T141539_IFCB152  D20210819T141539
#
#       ifcb            datetime
# 0  IFCB152 2021-08-18 16:27:00
# 1  IFCB152 2021-08-18 20:06:00
# 2  IFCB152 2021-08-19 02:01:19
# 3  IFCB152 2021-08-19 08:20:20
# 4  IFCB152 2021-08-19 14:15:39
# ['roi0', 'roi1', 'roi2', 'roi3', 'roi4', 'roi5', 'roi6', 'roi7', 'vfinal', 'inhibittime_final', 'looktime', 'pid', 'datetime_str', 'ifcb', 'datetime']

# %%
## Calculate inhibit/look raton
df["inhibitRatio"]= df["inhibittime_final"]/df["looktime"]

# %%
## Looks like one crazy value my guess is it is a bad sample so i am going to filter just the 99percentile of data
upper = df["inhibitRatio"].quantile(0.99)
df_filtered = df[df["inhibitRatio"] <= upper]

# %%
plt.figure()
plt.plot(df_filtered["datetime"], df_filtered["inhibitRatio"])
plt.xlabel("Datetime")
plt.ylabel("InhibitTime / LookTime")
plt.title("Inhibit Fraction Over Time")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure()
plt.boxplot(df_filtered["inhibitRatio"])
plt.xlabel("Nauset")
plt.ylabel("Inhibit Ratio")
#plt.xlim(1000)
# Jittered scatter
x = np.random.normal(1, 0.04, size=len(df_filtered["inhibitRatio"]))  # center at 1, small spread
plt.scatter(x, df_filtered["inhibitRatio"], alpha=0.5)
plt.tight_layout()
plt.show()

# %%
## next step is to do this for some data from  mvco and maybe a cruise and just put them all on the same plot to compare

# %%
### Thinking about rois 
df_filtered.describe()
# Out:
#               roi0          roi1         roi2         roi3         roi4  \
# count  1111.000000   1111.000000  1111.000000  1111.000000  1111.000000
# mean    148.253825   4229.180018   237.578758    17.724572     7.168317
# min       0.000000      8.000000     0.000000     0.000000     0.000000
# 25%       3.000000   2618.500000    92.000000     3.000000     0.000000
# 50%      15.000000   3770.000000   178.000000     6.000000     0.000000
# 75%      85.500000   5373.000000   333.000000    15.000000     0.000000
# max    3621.000000  12285.000000  3196.000000  2418.000000  3828.000000
# std     454.571586   2464.274907   233.177307   108.833296   124.104168
#
#               roi5         roi6         roi7       vfinal  inhibittime_final  \
# count  1111.000000  1111.000000  1111.000000  1111.000000        1111.000000
# mean      6.170117     5.254725     4.334833     3.341010         379.172909
# min       0.000000     0.000000     0.000000     0.055793           0.652363
# 25%       0.000000     0.000000     0.000000     2.836848         234.234748
# 50%       0.000000     0.000000     0.000000     3.481975         339.265382
# 75%       0.000000     0.000000     0.000000     3.980936         484.622049
# max    4165.000000  3258.000000  2527.000000     4.989134        1050.961667
# std     135.284415   118.768390   100.447797     0.904017         213.148199
#
#           looktime                       datetime  inhibitRatio
# count  1111.000000                           1111   1111.000000
# mean    801.842512  2023-06-17 01:59:44.740774144      0.652695
# min      13.390230            2021-08-18 16:27:00      0.000551
# 25%     680.843594            2022-06-23 17:13:08      0.250998
# 50%     835.674028            2022-09-17 14:17:28      0.411564
# 75%     955.424609            2024-09-25 18:56:14      0.690280
# max    1197.392194            2025-11-11 02:23:23      7.022472
# std     216.964067                            NaN      0.812822

# %%
plt.figure()
plt.boxplot(fildf["roi0"])
plt.xlabel("Nauset")
plt.ylabel("Roi# Type")
#plt.xlim(1000)
# Jittered scatter
# x = np.random.normal(1, 0.04, size=len(df_filtered["roi7"]))  # center at 1, small spread
# plt.scatter(x, df_filtered["roi7"], alpha=0.5)
plt.tight_layout()
plt.show()

# %%
print(df["roi5"].quantile(.99))
print(df["roi6"].quantile(.99))
print(df["roi7"].quantile(.99))
# Out:
# 8.899999999999864
# 4.679999999999836
# 0.0

# %%
filt = df["roi5"].quantile(.99)
fildf = df[df["roi5"] <= filt]

# %%
print(fildf["roi6"].max())
# Out:
# 6

# %%
df = df.sort_values("roi5")
print(df.tail(n=10))
# Out:
#      roi0   roi1  roi2   roi3  roi4  roi5  roi6  roi7    vfinal  \
# 148   982  10342  1076     84     8    10     0     0  0.858384
# 231   106    406    68     57     8    15     0     0  4.813580
# 364  2113   3483  2314    690   112    15     0     0  2.749565
# 167     0      0     8    345   232    30     0     0  4.943602
# 145   223   8916  1806    327    96    40     0     0  1.451332
# 363   618   7967  1874    540   236    75    60    14  1.449065
# 329   696    542   552    252   164   100    72    42  0.394383
# 166     2     10   340  26586  8032   480     0     0  1.098581
# 226    39    395   376    459   664   665   528   350  4.564845
# 222   178   1000   802   1008  1148  1240   900   595  4.033311
#
#      inhibittime_final     looktime                       pid  \
# 148         995.647361   206.012083  D20250625T201225_IFCB144
# 231          47.453364  1155.259136  D20250721T020437_IFCB145
# 364         612.206181   591.020347  D20260122T214559_IFCB144
# 167          15.019661  1186.464366  D20250630T141720_IFCB144
# 145         853.980417   348.319583  D20250625T021114_IFCB144
# 363         854.216597   347.775625  D20260122T161956_IFCB144
# 329         145.409948    94.651806  D20251010T203912_IFCB145
# 166         939.657431   263.659514  D20250630T081657_IFCB144
# 226         105.865859  1095.562891  D20250719T204129_IFCB145
# 222         233.449722   967.994722  D20250718T202350_IFCB145
#
#          datetime_str     ifcb            datetime  inhibitRatio
# 148  D20250625T201225  IFCB144 2025-06-25 20:12:25      4.832956
# 231  D20250721T020437  IFCB145 2025-07-21 02:04:37      0.041076
# 364  D20260122T214559  IFCB144 2026-01-22 21:45:59      1.035846
# 167  D20250630T141720  IFCB144 2025-06-30 14:17:20      0.012659
# 145  D20250625T021114  IFCB144 2025-06-25 02:11:14      2.451715
# 363  D20260122T161956  IFCB144 2026-01-22 16:19:56      2.456229
# 329  D20251010T203912  IFCB145 2025-10-10 20:39:12      1.536262
# 166  D20250630T081657  IFCB144 2025-06-30 08:16:57      3.563905
# 226  D20250719T204129  IFCB145 2025-07-19 20:41:29      0.096631
# 222  D20250718T202350  IFCB145 2025-07-18 20:23:50      0.241168
